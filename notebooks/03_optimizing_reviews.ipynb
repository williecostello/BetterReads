# %% [markdown]
# # BetterReads: Optimizing the number of reviews
#
# This notebook explores how many reviews are needed to achieve meaningful results with the BetterReads algorithm. We assume the general model framework laid out in the `01_modelling_with_use.ipynb` notebook and developed further in the `02_optimizing_kmeans.ipynb` notebook.
#
# We have two basic exploratory goals. The first goal is to determine how few review sentences we need to have for our algorithm to work as intended, so as to know how big our review datasets need to be. The second goal is to investigate whether filtering reviews by their rating leads to more meaningful or less meaningful results. Obviously, these two questions are related, as both concern the impact of the size of our dataset on the results of our model.

# %%
import numpy as np
import pandas as pd
import random

from sklearn.cluster import KMeans

import tensorflow_hub as hub

# %%
# Loads Universal Sentence Encoder locally, from downloaded module
embed = hub.load('../../Universal Sentence Encoder/module/')

# Loads Universal Sentence Encoder remotely, from Tensorflow Hub
# embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# %% [markdown]
# ## How many reviews does our algorithm need?
#
# Thus far we have been trialing our algorithm on fairly large datasets consisting of close to 10,000 reviews. Although plenty of books on GoodReads have this number of reviews, not all do, especially newer books. Furthermore, our web-scraping script can currently extract only up to 1,500 reviews for any given book. While we have access to larger datasets through UCSD Book Graph, these reviews are a few years old now, and limited in their scope. Ideally we would want our algorithm to be able to produce meaningful results for any book it is given, and to do so it must be able to work on smaller sets of reviews.
#
# ### Sampling sentences
#
# Our approach here will be as follows. Rather than simply seeing how our algorithm performs on smaller datasets directly, we will see how it performs on progressively smaller samples of a known larger dataset. This way we will have a sense, from its performance on the original dataset, of what results we should expect. If the algorithm starts to output drastically different results below a certain sample size, we can take this an indication that the sample size is too small.
#
# As in the previous notebooks, we will start by looking at *Gone Girl*.

# %%
def load_sentences(file_path):
    '''
    Function to load and embed a book's sentences
    '''
    
    # Read in processed file as dataframe
    df = pd.read_csv(file_path)
    
    print(f'This dataset consists of {df.shape[0]} sentences from {df["review_index"].nunique()} reviews\n')

    # Copy sentence column to new variable
    sentences = df['sentence'].copy()

    # Vectorize sentences
    sentence_vectors = embed(sentences)
    
    return sentences, sentence_vectors

# %%
def get_clusters(sentences, sentence_vectors, k, n):
    '''
    Function to extract the n most representative sentences from k clusters, with density scores
    '''
    
    # Instantiate the model
    kmeans_model = KMeans(n_clusters=k, random_state=24)

    # Fit the model
    kmeans_model.fit(sentence_vectors);

    # Set the number of cluster centre points to look at when calculating density score
    centre_points = int(len(sentences) * 0.02)
    
    # Initialize list to store mean inner product value for each cluster
    cluster_density_scores = []
    
    # Initialize dataframe to store cluster centre sentences
    df = pd.DataFrame()

    # Loop through number of clusters
    for i in range(k):

        # Define cluster centre
        centre = kmeans_model.cluster_centers_[i]

        # Calculate inner product of cluster centre and sentence vectors
        ips = np.inner(centre, sentence_vectors)

        # Find the sentences with the highest inner products
        top_indices = pd.Series(ips).nlargest(n).index
        top_sentences = list(sentences[top_indices])
        
        centre_ips = pd.Series(ips).nlargest(centre_points)
        density_score = round(np.mean(centre_ips), 5)
        
        # Append the cluster density score to master list
        cluster_density_scores.append(density_score)

        # Create new row with cluster's top 10 sentences and density score
        new_row = pd.Series([top_sentences, density_score])
        
        # Append new row to master dataframe
        df = df.append(new_row, ignore_index=True)

    # Rename dataframe columns
    df.columns = ['sentences', 'density']

    # Sort dataframe by density score, from highest to lowest
    df = df.sort_values(by='density', ascending=False).reset_index(drop=True)
    
    # Loop through number of clusters selected
    for i in range(k):
        
        # Save density / similarity score & sentence list to variables
        sim_score = round(df.loc[i]["density"], 3)
        sents = df.loc[i]['sentences'].copy()
        
        print(f'Cluster #{i+1} sentences (density score: {sim_score}):\n')
        print(*sents, sep='\n')
        print('\n')
        
    model_density_score = round(np.mean(cluster_density_scores), 5)
    
    print(f'Model density score: {model_density_score}')

# %%
# Set file path
gg_file_path = 'data/8442457_gone_girl.csv'

# Load and embed sentences
sentences, sentence_vectors = load_sentences(gg_file_path)
# Out:
# This dataset consists of 41873 sentences from 8275 reviews

# %%
# Get cluster sentences
get_clusters(sentences, sentence_vectors, k=9, n=8)
# Out:
# Cluster #1 sentences (density score: 0.538):
#
# I was kind of disappointed with the ending but it was a real ending.
# I wasn't a huge fan of the ending.
# I don't think I liked the ending.
# I wasn't a huge fan of the ending but at the same time, the ending made sense with the story.
# Although I didn't like the ending - it left me wanting an ending.
# Definitely a page-turner, but I didn't like the ending.
# I thought the ending was AWFUL.
# I really didn't care for the ending.
#
#
# Cluster #2 sentences (density score: 0.459):
#
# Gillian Flynn is a good storyteller but I'm not sure that I'll read another of her books.
# Gillian Flynn is a good writer and she had me fooled.
# Let's start with the fact that Gillian Flynn is an excellent writer.
# Gillian Flynn though, is clearly a good writer.
# Gillian Flynn is an awesome writer.
# Gillian Flynn is a brilliant writer.
# I'm definitely going to be reading another Gillian Flynn book.
# Gillian Flynn is an amazing writer.
#
#
# Cluster #3 sentences (density score: 0.443):
#
# This book was great - I just couldn't put it down.
# I was so into this book but I honestly didnt understand the last chapter of the book!!!
# Dont get me wrong i did enjoy reading this book very much.
# Don't get me wrong, this book was thoroughly engrossing.
# Aside from the easy read, I really didn't like this book.
# I've been wanting to read this book for a long time.
# I doubt this book is for everyone but I really enjoyed it!
# I thought this book was going to be good, I really did.
#
#
# Cluster #4 sentences (density score: 0.385):
#
# I'm just glad to be away from both Nick and Amy; they ruined a compelling and twisty narrative.
# How the story jumps between Nick and Amy's diary is fantastic at showing the present and the how Amy came up to being dead and resenting Nick.
# Amy is married to Nick, and the book starts out with Amy going missing.
# Nick was cheating on Amy for over a year and Amy had some secrets even Nick would have been shocked to find out!
# As far as characters go, I found both Nick and Amy to be absolutely fascinating.
# Still seems like there is more to tell of the Nick and Amy story.
# Nick and Amy's parents have plenty of possible suspects because people are always so obsessed with Amy.
# At the beginning of the story, I didn't really much care for Nick or for Amy.
#
#
# Cluster #5 sentences (density score: 0.369):
#
# It was a very quick read and I enjoyed the twists in the plot.
# The book has an intriguing premise, and shocking twists, but I wanted a more satisfying ending.
# The plot has so many twists and turns in it that I felt it was a little hard to keep up and defantly hard to figure out the ending, which I do in a murder mystery novel.
# The suspense was great and the plot twists were very interesting, however, it just ended.
# I loved the plot twists and the unexpected turns in this tale.
# I guess that's what thrillers are supposed to do, but I enjoyed the twists and plot surprises before it became anti-climactic.
# It is an amazing psychological thriller, very well written and full of plot twists and turns.
# The writing was excellent, the plot twists were surprising, it was suspenseful and i couldn't put it down.
#
#
# Cluster #6 sentences (density score: 0.359):
#
# The characters are totally unlikable but the story is interesting and hard to put down.
# I loathed both of the main characters and yet loved the story.
# I felt it was well written, but I couldn't stand any of the characters, which may have been what the author intended.
# Book was well written and engrossing, but I disliked both main characters so much, it was hard to care about what happened to them.
# Otherwise, I really did enjoy the book and thought the characters were really interesting, different from the usual cast of characters.
# I don't always have to love the characters in a story to be engrossed, but when I'm also disappointed in a book overall it's easier to really start hating unlikable characters.
# I truly enjoyed the love-hate relationship that the reader has with the characters (although the same can be said for the characters themselves).
# I was involved in the characters' stories from the first page and, even though there are really no likable characters, I had to know what happened next.
#
#
# Cluster #7 sentences (density score: 0.308):
#
# I loved it until the end which I found to be disappointing.
# It kept me reading later than I should have but I was kinda disappointed in the end.
# I started skimming towards the end because I just couldn't stand it.
# I thought I was going to like this when I started reading it but the further into it I got the less I liked it.
# It took me a long time to get into it, then I liked it, then I didn't.
# Like most people, I thought the end was a bit of a let down.
# Well, this was a great read as far as me not wanting to put it down.
# I was definitely shocked over and over while reading, right up to the end.
#
#
# Cluster #8 sentences (density score: 0.264):
#
# Deliciously nasty novel about a husband and wife who truly hate each other; when the wife ends up missing, who's to blame?
# I cannot say too much about the plot other than it tells of a bad marriage, which becomes worse as the story unfolds, and the disappearance of the wife on the couple's 5th anniversary.
# Most people are familiar with the premise, marriage gone bad, wife disappears, and the husband is the main suspect of foul play.
# This is a very well-written and creepy story about a completely dysfunctional marriage and the extreme lengths to which Amy Dunne goes to get the upper hand over her husband, Nick.
# This is a well written, terrifying insight into the minds of a married couple where the wife disappears on their fifth anniversary.
# The book takes you into the minds of a cheating husband and a revengeful wife and their intake in to their collapsing marriage.
# My one sentence summary:   A troubled marriage and a missing wife are just the beginning of a story about two people who might just be made for each other because of what they are willing to put the other through.
# This story is from the point of view of a husband and wife, and it becomes very clear that there is something not quite right with this marriage.
#
#
# Cluster #9 sentences (density score: 0.158):
#
# It was so disturbingly messed up in a wonderful "I need to keep reading" type of way!
# I'm pretty sure I hate it, but it might just be brilliant.
# I don't dare say much more as it gives away the plot line.
# Well, that's one of the most messed up things I've read in a long, long, while.
# I'd like to say more but don't want to ruin the story for anyone.
# That said, it's a deeply weird story.
# It flowed well, even though it was just unwrapping one terrible thing after another.
# It's got a great plot, but that's not the best part.
#
#
# Model density score: 0.36491

# %% [markdown]
# As we saw in previous notebooks, when we run our algorithm on the the full dataset with k = 9 clusters, our algorithm identifies the following nine broad themes in the reviews:
#
# 1. Didn't like the ending
# 1. Gillian Flynn is an excellent writer
# 1. Couldn't put it down
# 1. Main characters (Nick and Amy)
# 1. Plot twists & turns
# 1. Awful characters, great story
# 1. Loved the book, but not the ending
# 1. A story of a bad marriage
# 1. Messed up & disturbing
#
# Not all of these themes are entirely distinct, but we should expect to see several of them in any smaller sample we take.
#
# We will begin by taking random samples of the full dataset and keeping the numbers of clusters set at 9. As we decrease the size of our dataset we may need to decrease the number of clusters, but that is something we will investigate further down the line.
#
# Let us start by taking a 50% sample of our data and inspect the results. (Note that, by taking a 50% sample of sentences, we will not achieve of 50% sample of reviews, since some reviews have more sentences than others. Whether this makes a difference to our algorithm is something else we'll investigate further on.)

# %%
def get_sample(file_path, frac):
    '''
    Function to take a random sample of a dataset's sentences
    '''
    
    # Read in file as dataframe
    df = pd.read_csv(file_path)
    
    # Take the sample
    sample_df = df.sample(frac=frac, random_state=24).reset_index(drop=True)
    print(f'This sample consists of {sample_df.shape[0]} sentences from {sample_df["review_index"].nunique()} reviews\n')
    
    # Copy sentence column to new variable
    sentences = sample_df['sentence'].copy()

    # Vectorize sentences
    sentence_vectors = embed(sentences)
    
    return sentences, sentence_vectors

# %%
# Get sentence clusters from a 50% sample of our dataset
sentences, sentence_vectors = get_sample(gg_file_path, 0.5)
get_clusters(sentences, sentence_vectors, k=9, n=8)
# Out:
# This sample consists of 20936 sentences from 6759 reviews
#
# Cluster #1 sentences (density score: 0.538):
#
# Definitely a page-turner, but I didn't like the ending.
# I liked the book, but the ending was not what I expected AT ALL!
# The ending was a total anti-climax - I see the intention of the ending but it irritated me.
# I must admit I hated the ending.
# I wish the ending had been better, but I guess the particular ending was supposed to be that way.
# I was a little disappointed in the ending, but the rest of the book was so good, it didn't matter.
# I didn't like the ending at all by the way.
# Some people didn't like the ending but I found that the ending was just right.
#
#
# Cluster #2 sentences (density score: 0.461):
#
# Gillian Flynn is a good storyteller but I'm not sure that I'll read another of her books.
# Let's start with the fact that Gillian Flynn is an excellent writer.
# Gillian Flynn though, is clearly a good writer.
# Gillian Flynn is a brilliant writer.
# I love the way Gillian Flynn writes.
# Gillian Flynn is clearly a talented writer.
# Gillian Flynn is a wonderful writer.
# Gillian Flynn is a good writer.
#
#
# Cluster #3 sentences (density score: 0.444):
#
# This book was great - I just couldn't put it down.
# Dont get me wrong i did enjoy reading this book very much.
# I've been wanting to read this book for a long time.
# I almost didn't read this book, I'd heard/read so much about it.
# This book is one of the best books I have read in a long time!
# Book kept me intrigued enough but somehow I figured this book long before the end.
# This book was recommended to me so many times that I had to read it.
# I actually REALLY liked this book.
#
#
# Cluster #4 sentences (density score: 0.385):
#
# Once it happened and Real Amy explained everything, the book just sort of puttered on for a while, Nick insisting he had to get Amy home and Amy doing nothing of interest or value.
# At the beginning of the story, I didn't really much care for Nick or for Amy.
# Nick and Amy appear to have the perfect marriage but all that changes on their fifth anniversary when Amy disappears and the police begin to suspect Nick had something to do with it.
# But there is a catch her, Amy has a dark side and Nick does not know about it and the story starts going back and forth between the two as Amy disappears and Nick is accused of murder.
# Amy's side of the story sort of dragged for me, we'd already been through the first few days with Nick, that reading about Amy watching Nick under media scrutiny was a bit repetitive.
# I have to say I hated Nick and Amy, towards the end I hated Nick a little less than Amy.
# I loved the premise of having the day Amy disappears from Nick's point of view juxtaposed with Amy's diary from when they first met and onward.
# I couldn't figure out if Nick had really killed Amy.
#
#
# Cluster #5 sentences (density score: 0.367):
#
# It was a very quick read and I enjoyed the twists in the plot.
# The book has an intriguing premise, and shocking twists, but I wanted a more satisfying ending.
# The plot has so many twists and turns in it that I felt it was a little hard to keep up and defantly hard to figure out the ending, which I do in a murder mystery novel.
# I loved the plot twists and the unexpected turns in this tale.
# The writing was excellent, the plot twists were surprising, it was suspenseful and i couldn't put it down.
# The ending was not what I expected, but overall Gone Girl was a good book with a lot of unexpected twists and turns!
# I was hoping for a different ending, but the twists of the plot were intriguing and well done.
# Well written, very suspenseful with many great plot twists.
#
#
# Cluster #6 sentences (density score: 0.354):
#
# I loathed both of the main characters and yet loved the story.
# It is amazing how hard it is to write a positive review about a story in which I distinctly dislike both the main characters.
# I don't always have to love the characters in a story to be engrossed, but when I'm also disappointed in a book overall it's easier to really start hating unlikable characters.
# Loved the story, but the characters drove me crazy.
# I did not like the characters in this book and I felt like it dragged at times.
# I despised both main characters not to mention the obvious anti-Midwest attitude of the author.
# I love characters who are flawed and complex, but I felt that the main characters in the book (and even the supporting characters) were terribly unlikeable.
# The plot was interesting, but ALL of the characters were not likable, and I found myself rolling my eyes at how ridiculous their perspectives were.
#
#
# Cluster #7 sentences (density score: 0.305):
#
# It kept me reading later than I should have but I was kinda disappointed in the end.
# I started skimming towards the end because I just couldn't stand it.
# I was definitely shocked over and over while reading, right up to the end.
# It took me a long time to get into it, then I liked it, then I didn't.
# Well, this was a great read as far as me not wanting to put it down.
# Like most people, I thought the end was a bit of a let down.
# I couldn't even read the entire thing I hated it so much.
# I hated it, and yet I couldn't stop reading it.
#
#
# Cluster #8 sentences (density score: 0.268):
#
# I cannot say too much about the plot other than it tells of a bad marriage, which becomes worse as the story unfolds, and the disappearance of the wife on the couple's 5th anniversary.
# Most people are familiar with the premise, marriage gone bad, wife disappears, and the husband is the main suspect of foul play.
# This is a very well-written and creepy story about a completely dysfunctional marriage and the extreme lengths to which Amy Dunne goes to get the upper hand over her husband, Nick.
# The book takes you into the minds of a cheating husband and a revengeful wife and their intake in to their collapsing marriage.
# This is a well written, terrifying insight into the minds of a married couple where the wife disappears on their fifth anniversary.
# A thriller about a twisted marriage, told in a suspenseful way, with carefully-designed sudden reversals that change how you view the husband and the wife.
# This story is from the point of view of a husband and wife, and it becomes very clear that there is something not quite right with this marriage.
# My one sentence summary:   A troubled marriage and a missing wife are just the beginning of a story about two people who might just be made for each other because of what they are willing to put the other through.
#
#
# Cluster #9 sentences (density score: 0.157):
#
# I'm pretty sure I hate it, but it might just be brilliant.
# I don't dare say much more as it gives away the plot line.
# Well, that's one of the most messed up things I've read in a long, long, while.
# I'd like to say more but don't want to ruin the story for anyone.
# I have never been so conflicted on how I feel about a book.
# Ultimately, though, I think this is just not my kind of book.
# Great twists that I wasn't expecting but she just really pissed me off.
# Well written, for sure, but man oh man.
#
#
# Model density score: 0.36442

# %% [markdown]
# As we can see, a 50% sample still produces perfectly intelligible results. Let's summarize each of the identified clusters:
#
# 1. Didn't like the ending
# 1. Gillian Flynn is an excellent writer
# 1. Couldn't put it down
# 1. Main characters (Nick and Amy)
# 1. Plot twists & turns
# 1. Awful characters, great story
# 1. Loved the book, but not the ending
# 1. A story of a bad marriage
# 1. Messed up & disturbing
#
# In other words, the algorithm identifies exactly the same thematic clusters as before (though in a different order, since the order of k-means clusters is random and not of any significance). Furthermore, the density scores of the individual clusters are nearly all the same, and the overall model density score is also virtually identical. This suggests that our model has not lost any significant information by taking a 50% sample of our data.
#
# Let's then see how things turn out with smaller samples. How about a 25% sample?

# %%
# Get sentence clusters from a 25% sample of our dataset
sentences, sentence_vectors = get_sample(gg_file_path, 0.25)
get_clusters(sentences, sentence_vectors, k=9, n=8)
# Out:
# This sample consists of 10468 sentences from 4958 reviews
#
# Cluster #1 sentences (density score: 0.543):
#
# I liked the book, but the ending was not what I expected AT ALL!
# The ending was a total anti-climax - I see the intention of the ending but it irritated me.
# I must admit I hated the ending.
# I didn't like the ending at all by the way.
# That said, I didn't like the ending, and I didn't actually like a lot of the book.
# I liked everything but the ending.
# Loved the story right up until the end, very disappointed in the ending.
# Anyway, it's well written even if i didn't get the ending i was expecting.
#
#
# Cluster #2 sentences (density score: 0.462):
#
# Gillian Flynn though, is clearly a good writer.
# Let's start with the fact that Gillian Flynn is an excellent writer.
# I love the way Gillian Flynn writes.
# Gillian Flynn is clearly a talented writer.
# Gillian Flynn is a wonderful writer.
# Gillian Flynn is a good writer though, and I can't wait to read her other novels.
# Gillian Flynn is such an incredible author.
# Gillian Flynn is an incredibly gifted writer.
#
#
# Cluster #3 sentences (density score: 0.445):
#
# This book was great - I just couldn't put it down.
# I've been wanting to read this book for a long time.
# I almost didn't read this book, I'd heard/read so much about it.
# I actually REALLY liked this book.
# This book was very well-written and one of the most interesting books I've ever read.
# I liked this book, I think it's a good book.
# Honestly I read this book since everyone else was raving about it.
# This book was recommended to me so many times that I had to read it.
#
#
# Cluster #4 sentences (density score: 0.384):
#
# Once it happened and Real Amy explained everything, the book just sort of puttered on for a while, Nick insisting he had to get Amy home and Amy doing nothing of interest or value.
# But there is a catch her, Amy has a dark side and Nick does not know about it and the story starts going back and forth between the two as Amy disappears and Nick is accused of murder.
# I just couldn't stand the kind of people Nick and Amy were.
# I couldn't figure out if Nick had really killed Amy.
# Amy's side of the story sort of dragged for me, we'd already been through the first few days with Nick, that reading about Amy watching Nick under media scrutiny was a bit repetitive.
# I hate nick even more after finding out what he's done to Amy!
# Nick and Amy appear to have the perfect marriage but all that changes on their fifth anniversary when Amy disappears and the police begin to suspect Nick had something to do with it.
# I just don't give a damn about Nick and Amy.
#
#
# Cluster #5 sentences (density score: 0.367):
#
# It was a very quick read and I enjoyed the twists in the plot.
# The book has an intriguing premise, and shocking twists, but I wanted a more satisfying ending.
# The ending was not what I expected, but overall Gone Girl was a good book with a lot of unexpected twists and turns!
# The writing was excellent, the plot twists were surprising, it was suspenseful and i couldn't put it down.
# The plot is full of twists and turns and I never would have guessed the ending.
# Well written, very suspenseful with many great plot twists.
# This was an interesting book to say the least and definitely has quite a few plot twists.
# Great suspense novel but really hated the ending.
#
#
# Cluster #6 sentences (density score: 0.356):
#
# It is amazing how hard it is to write a positive review about a story in which I distinctly dislike both the main characters.
# Loved the story, but the characters drove me crazy.
# I despised both main characters not to mention the obvious anti-Midwest attitude of the author.
# There weren't any likeable characters in this book and that's why I liked it.
# I really wanted to like this book, but UGH both of the main characters were such horrible people.
# The characters are so unlikeable I was literally enraged while reading it.
# I absolutely hated both the main characters but in a good way.
# I had little like or sympathy for any of the characters, yet I was drawn to finishing the story.
#
#
# Cluster #7 sentences (density score: 0.302):
#
# It took me a long time to get into it, then I liked it, then I didn't.
# On the down side, it actually made ME feel tense the entire time I was reading it, from beginning to end.
# I will probably never read it again, and I now have very little to say about it.
# I kept reading because I wanted to find out what happened and because everyone said it was so good.
# I'm not sure I enjoyed it, but I thought it was compelling to read.
# Too bad, because I mostly enjoyed it.
# I am still not sure how I feel about the ending.
# I just couldn't put it down and get it out of my head for days.
#
#
# Cluster #8 sentences (density score: 0.285):
#
# Most people are familiar with the premise, marriage gone bad, wife disappears, and the husband is the main suspect of foul play.
# I cannot say too much about the plot other than it tells of a bad marriage, which becomes worse as the story unfolds, and the disappearance of the wife on the couple's 5th anniversary.
# This is a well written, terrifying insight into the minds of a married couple where the wife disappears on their fifth anniversary.
# A thriller about a twisted marriage, told in a suspenseful way, with carefully-designed sudden reversals that change how you view the husband and the wife.
# A tale about a TRUE bad romance starting with the disappearance of a wife with the husband being the number one suspect-something we hear about almost daily.
# This is a story of a marriage gone terribly wrong, where, on the couple's 5th anniversary, the wife just disappears.
# Gone Girl is a story of a woman that goes missing on the day of her 5th wedding anniversary, and all the evidence points straight to her husband as the killer.
# The book starts with the missing girl and moves a little slowly at the beginning and makes you wonder what the fuss is all about - a simple story - husband hates wife and kills her.
#
#
# Cluster #9 sentences (density score: 0.157):
#
# I don't dare say much more as it gives away the plot line.
# Well written, for sure, but man oh man.
# Ultimately, though, I think this is just not my kind of book.
# Well to be precise this is not a nice story for starters but it is really psycho.
# Seriously can't believe it was left that way.
# It's got great writing, but that's not the best part.
# The ending is so absurd and preposterous which just makes it even worse that I read the whole thing.
# I am still not sure how I feel about the ending.
#
#
# Model density score: 0.36679

# %% [markdown]
# Much the same results, with no significant drops in density score! Let's try going even lower...

# %%
# Get sentence clusters from a 90% sample of our dataset
sentences, sentence_vectors = get_sample(gg_file_path, 0.1)
get_clusters(sentences, sentence_vectors, k=9, n=8)
# Out:
# This sample consists of 4187 sentences from 2801 reviews
#
# Cluster #1 sentences (density score: 0.537):
#
# I liked the book, but the ending was not what I expected AT ALL!
# I must admit I hated the ending.
# Loved the story right up until the end, very disappointed in the ending.
# The only thing that disappointed me tremendously was the ending.
# I was somewhat disappointed in the ending (I won't spoil it) but in a way, I'm not sure what other ending would really suit the story.
# I wasn't crazy about the ending, but then, it was kind of appropriate.
# The ending was different than expected, but I'm happy it was.
# I am not too sure I like the ending, but I enjoyed the book.
#
#
# Cluster #2 sentences (density score: 0.469):
#
# Gillian Flynn though, is clearly a good writer.
# I love the way Gillian Flynn writes.
# Gillian Flynn is clearly a talented writer.
# Gillian Flynn is a wonderful writer.
# Gillian Flynn is such an incredible author.
# Gillian Flynn is an incredibly gifted writer.
# Gillian Flynn is a beautiful writer.
# I'm excited to read more of Gillian Flynn.
#
#
# Cluster #3 sentences (density score: 0.459):
#
# I've been wanting to read this book for a long time.
# I liked this book, I think it's a good book.
# This book was very well-written and one of the most interesting books I've ever read.
# I really, really wanted to love this book.
# I read this book very quickly; it's one of those books that actually lives up to its "unputdownable" status.
# This book was my kind of book.
# I wasn't a fan of this book.
# Over all, I enjoyed this book.
#
#
# Cluster #4 sentences (density score: 0.376):
#
# Nick and Amy appear to have the perfect marriage but all that changes on their fifth anniversary when Amy disappears and the police begin to suspect Nick had something to do with it.
# But there is a catch her, Amy has a dark side and Nick does not know about it and the story starts going back and forth between the two as Amy disappears and Nick is accused of murder.
# Once it happened and Real Amy explained everything, the book just sort of puttered on for a while, Nick insisting he had to get Amy home and Amy doing nothing of interest or value.
# Mid-way through the book it becomes clear that Nick and Amy kept secrets from each other.
# I very much enjoyed Nick and Amy as well as Amy's parents and Nick's sister.
# I love completely messed up characters and although Amy is definitely more messed up, I don't think Nick is very far behind.
# nick and amy are just sick that like they said they are perfect for each other!
# Nick and Amy are so detestable in both their personalities and their actions, especially how they capitulate at the end.
#
#
# Cluster #5 sentences (density score: 0.362):
#
# There weren't any likeable characters in this book and that's why I liked it.
# I despised both main characters not to mention the obvious anti-Midwest attitude of the author.
# I had little like or sympathy for any of the characters, yet I was drawn to finishing the story.
# It was a clever story with a lot of very unlikable characters.
# The characters, though well written, are just super crappy people.
# The characters were fascinating and complex enough that I didn't mind how completely unlikable they were.
# hated all the characters, but couldn't stop reading.
# Yes, the main characters are despicable people, but that did not get in the way of my enjoyment of the story.
#
#
# Cluster #6 sentences (density score: 0.347):
#
# It was a very quick read and I enjoyed the twists in the plot.
# Lots of suspense and unexpected twists make this creative mystery an excellent read.
# I was suspenseful and surprising with lots of twists.
# Haven't read a book with so many plot twists in a long time!
# I totally recommend it for all the plot twists and dark writing but, wish I had gotten more at the end.
# A great read, very suspenseful, full of twists and unexpected surprises.
# Great book, lots of twists & turns, disappointing ending tho!
# There were so many twists and turns in the plot, it was a real roller coaster of a read.
#
#
# Cluster #7 sentences (density score: 0.322):
#
# It took me a long time to get into it, then I liked it, then I didn't.
# On the down side, it actually made ME feel tense the entire time I was reading it, from beginning to end.
# I thought it was a good read, a little long but it kept me interested.
# I'm not sure I enjoyed it, but I thought it was compelling to read.
# Well I thought it was going to be one of the best books I've ever read until I got to the end.
# I only spent a day or two on it because I was so wrapped up in the story that I couldn't stop reading.
# I was completely hooked and couldn't stop thinking about the plot when I had to put it down.
# I truly enjoyed reading it until the very end.
#
#
# Cluster #8 sentences (density score: 0.231):
#
# Most people are familiar with the premise, marriage gone bad, wife disappears, and the husband is the main suspect of foul play.
# I cannot say too much about the plot other than it tells of a bad marriage, which becomes worse as the story unfolds, and the disappearance of the wife on the couple's 5th anniversary.
# She is a whole new level of crazy, she faked her death and escaped to nail her husband for cheating on her, well not even cheating, for not being the perfect husband and for not loving her unconditionally.
# a page-turner and intriguing look into the minds of a husband and wife in a marriage on the brink of disaster.
# It is a story about a couple who got together for the wrong reasons, and they are both two awful people.
# A thriller about a twisted marriage, told in a suspenseful way, with carefully-designed sudden reversals that change how you view the husband and the wife.
# This is the story of a marriage and the secrets inside it that sometimes even a spouse doesn't know about.
# Gone Girl is a story about a marriage that is hijacked buy something twisted, a need to play and make people learn their lessons.
#
#
# Cluster #9 sentences (density score: 0.18):
#
# I'm left with a sense of yeah, we all know where this is going.
# All I can say is Wow, I didn't see that coming.
# I suspected that's where she was going all along.
# At least now I know what all the fuss was about.
# Not sure I love the ending, I'll leave it at that.
# I was hoping that it would at least be a decent read.
# I couldn't put it down, I had to know how this would all play out.
# I honestly can't remember the last time a book messed with me like this and had me guessing right up to the end.
#
#
# Model density score: 0.36484

# %% [markdown]
# Again, the results here look good. Can we go even lower?

# %%
# Get sentence clusters from a 99% sample of our dataset
sentences, sentence_vectors = get_sample(gg_file_path, 0.01)
get_clusters(sentences, sentence_vectors, k=9, n=8)
# Out:
# This sample consists of 419 sentences from 396 reviews
#
# Cluster #1 sentences (density score: 0.511):
#
# Unfortunately I was extremely disappointed with the ending.
# Not sure I love the ending, I'll leave it at that.
# I would have given it 5 stars, but I absolutely hated the ending.
# i didn't hate that ending, but i didn't feel completely satisfied by it either.
# I literally just finished it so SPOILER ALERT   I hated the ending!!!
# The ending disappointed me, to be honest.
# The only thing which I found slightly disappointing about this book is the ending.
# def not a fan of the ending!
#
#
# Cluster #2 sentences (density score: 0.491):
#
# Gillian Flynn is a wonderful writer.
# Needless to say I probably won't be reading another of Gillian Flynn's books anytime soon.
# In the end, I am still awed and fascinated by the characters gillian flynn created, and I can't wait to talk about this book with the friend who gave it to me and with everyone else who reads it.
# One of my top favorites for sure and now I am looking forward to reading Gillian Flynn's other books.
# I am definitely going to read more by Flynn.
# Gillian Flynn is very good at grabbing her readers and keeping them hooked.
# I'm waiting Gillian Flynn - GET ON IT!
# I am fascinated and want to read more of Gillian Flynn's books.
#
#
# Cluster #3 sentences (density score: 0.456):
#
# I really, really wanted to love this book.
# First, I have to say that I read this book almost on a whim.
# I can't decide how much I liked this book.
# This book is AWFUL, and I mean that in a really good way!!!
# There are only a few books that can captivate me as much as this book did.
# I had a very hard time getting into this book.
# I took me a while to actually start liking this book but God damn!
# This book had me all the way up to the last 50 pages.
#
#
# Cluster #4 sentences (density score: 0.401):
#
# I was totally hoping for the cliche ending where Amy is exposed, and Nick is set free.
# At the very beginning I disliked Amy, not sure why; but after a while I started hating Nick and sympathizing for Amy, until the second part started and.
# I wanted the 'right' ending where Amy gets punished and Nick moves on with his kinda sad life.
# The premise of this book is that Amy, the wife to Nick has gone missing and as more information comes to light about their relationship and Nick's reactions he naturally comes under suspicion.
# Once I found out how crazy Amy's character really was, I felt so bad for thinking it was Nick at all.
# This is the story of a disillusioned and unhappy couple Nick and Amy, who after both being made redundant have moved to Missouri, where Nick grew up, and have continued to resent each other just as much.
# It meanders along as it shares the story of Amy and Nick, a couple married for five years.
# I don't know who is more crazy in the story: Nick or Amy.
#
#
# Cluster #5 sentences (density score: 0.389):
#
# Yes, the main characters are despicable people, but that did not get in the way of my enjoyment of the story.
# I just didn't care much for any of the characters.
# In the end, I just didn't like any of the characters.
# Well, I have a problem when I really don't like any of the characters in the book.
# The level of depravity within these characters is astounding; which for me made this book thoroughly enjoyable.
# Very interesting book- in which I didn't like either of the main protagonists but the author created such a page turning story that I was compelled to read to the end.
# I usually don't care for stories told from different points of view of different characters.
# There are some merits to the writing, but the twist left me cold and destroyed the sympathy that the characters had built through exploring their faults.
#
#
# Cluster #6 sentences (density score: 0.333):
#
# Wow--what a brilliant thriller (and I don't usually enjoy thrillers!).
# Gone Girl was a psychological thriller written in a creative way.
# One of the best thrillers i've ever read.
# The book was more than a brilliant thriller.
# For anyone who loves a good mystery or suspense thriller, this novel will keep you on the edge of your seat.
# Loved the twists and turns of this book.
# The story is part crime solver, murder drama and psycho-movie with a very noticeable twist in the last chunk of pages.
# Apart from that, it was the best thriller I've read in a long, long time.
#
#
# Cluster #7 sentences (density score: 0.301):
#
# I couldn't predict what would happen but everything that happened felt believable based on who the characters were.
# I honestly can't remember the last time a book messed with me like this and had me guessing right up to the end.
# I was able to figure out the main twist pretty quickly, because I'm cynical like that, but omg the HOW of it?
# The ending was not what I imagined, and what very much different from what I was hoping for, but so interesting anyway.
# Great in a "she made the story really interesting" kind of way. )
# It was definitely a pageturner with twists and turns combined in a way that I had never seen before.
# I don't believe the story would be edifying for a young mind.
# I can't recall a single amazing thing I have seen firsthand that I didn't immediately reference to a movie or TV show.
#
#
# Cluster #8 sentences (density score: 0.246):
#
# I had to force myself to get that far.
# I might need to think about it for a while.
# went on a wee bit too long though
# Took me forever to get through.
# The end wrapped up in a way I was slightly disappointed in, but I'm not sure there's a good way to end such a wild ride.
# This was one of the first real page-turner's I've had in a while.
# Not sure I love the ending, I'll leave it at that.
# I just know I don't like how it ended.
#
#
# Cluster #9 sentences (density score: 0.235):
#
# Takes love and marriage to a whole new level.
# How he managed to stay in the marriage for that long is beyond words.
# All it needed was a bad marriage coupled with serious and diabolical instability on the part of one half of the couple.
# Loved how this story explores marriage.
# They're fascinating and their marriage even more so.
# What I actually got was an explosive, thought provoking journey about a toxic, destructive relationship between two people and the priorities in their marriage.
# What would she become now?~ Hey, you married her.
# A woman disappears one day, and the question is: did her husband kill her?
#
#
# Model density score: 0.37359

# %% [markdown]
# Remarkably, even with only a 1% sample of our original dataset – only 419 sentences – our model still identifies same nine broad clusters as it originally did. This is a very strong indication of two things: first, that the clusters that our original model identified are indeed representative of the most commonly expressed in the dataset; and second, that our model can still produce meaningful results from a very small dataset of reviews.
#
# ### Sampling reviews
#
# There is, however, a potential weakness in how we've been proceeding thus far. In all of the above examples we have been sampling our dataset at the *sentence* level. Yet this is not the best indicator of how our model will perform on smaller sets of *reviews*. So let us now sample our dataset at the level of its reviews.

# %%
def get_review_sample(file_path, frac):
    '''
    Function to take a random sample of a dataset's reviews
    '''
    
    # Read in file as dataframe
    df = pd.read_csv(file_path)
    
    # Find the number of reviews in the dataset
    num_reviews = df['review_index'].nunique()
    
    # Calculate number of reviews to include in sample
    sample_size = int(num_reviews * frac)

    # Create a list of all review indices in dataset
    review_ids = df['review_index'].unique()

    # Take a random sample of these reviews indicates
    sample_reviews = random.sample(set(review_ids), sample_size)

    # Create dataframe of sentences from the sampled reviews
    sample_df = df[df['review_index'].isin(sample_reviews)].reset_index(drop=True)
    
    print(f'This sample consists of {sample_df.shape[0]} sentences from {sample_df["review_index"].nunique()} reviews\n')
    
    # Copy sentence column to new variable
    sentences = sample_df['sentence'].copy()

    # Vectorize sentences
    sentence_vectors = embed(sentences)
    
    return sentences, sentence_vectors

# %%
# Get sentence clusters from a 90% review sample of our dataset
random.seed(24)
sentences, sentence_vectors = get_review_sample(gg_file_path, 0.1)
get_clusters(sentences, sentence_vectors, k=9, n=8)
# Out:
# This sample consists of 4170 sentences from 827 reviews
#
# Cluster #1 sentences (density score: 0.53):
#
# Loved the story right up until the end, very disappointed in the ending.
# Personally, seeing what the book turned into towards the end (in this it's a good thing), I thought that the ending was great.
# Just wasn't crazy about the ending.
# I didn't like the ending though.
# While I can't say that I liked the ending, I thought it was perfect for the book.
# I am really disappointed in the ending, but the rest of the book was amazing.
# Not sure I liked the ending though.
# Good story, but I didn't like the ending.
#
#
# Cluster #2 sentences (density score: 0.479):
#
# Gillian Flynn is an amazing writer.
# I love the way Gillian Flynn writes!
# Gillian Flynn is an author I'm definitely going to look out for.
# Gillian Flynn is a beautiful writer.
# Gillian Flynn is an incredibly gifted writer.
# I really applaud the way that Gillian Flynn could explore all the psychological aspects of the book.
# Lots of Kudos to Gillian Flynn for such a terrific read!
# After this, I set out to read all of Gillian Flynn novels - and haven't been disappointed yet.
#
#
# Cluster #3 sentences (density score: 0.437):
#
# I didn't really like this book.
# Honestly I read this book since everyone else was raving about it.
# I don't know that I could recommend this book; I didn't enjoy it, but it was a compelling read.
# I really, really wanted to like this book.
# I thought this book was fantastic.
# This book was very well written but definitely not a feel good book at all.
# What I liked about this book was that it made me want to keep reading it until the very end.
# I liked this book until half way through.
#
#
# Cluster #4 sentences (density score: 0.382):
#
# I'm just glad to be away from both Nick and Amy; they ruined a compelling and twisty narrative.
# Amy and Nick have been married for 5 years on the day that Amy goes missing.
# I just couldn't stand the kind of people Nick and Amy were.
# Nick for being so weak and stupid, and Amy for being Amy.
# I was dumbfounded by the ending and the way Amy got her way and a little surprised that Nick decided to stay with her.
# The first part of the book is back and forth counterpoint between Nick recounting Amy's disappearance and Amy's journal recounting her life with Nick.
# *SPOILER ALERT*   The chapters about Amy's dairies, there were something strange about how Amy described her relationship with her husband Nick.
# Gradually, Nick's story appears, and it seems that he may not be entirely to blame for the disastrous state of Nick and Amy's marriage.
#
#
# Cluster #5 sentences (density score: 0.366):
#
# The book was very interesting, the suspense built, it had some really interesting twists.
# Final thoughts   Gone Girl is a great novel, full of suspense and plot twists.
# Fantastic plot twists and truly mind-boggling behaviour from its protagonists make this an engaging read.
# I liked the twists which made it a good fast read but the end was anticlimactic
# The ending was not what I expected, but overall Gone Girl was a good book with a lot of unexpected twists and turns!
# There's very little I can say about the actual storyline, as this thriller has so many plot twists it would be a shame to spoil it.
# I loved this book - there were many twists and turns and I love a good psychological thriller!
# I really enjoyed this book and thought it was a great twist on the typical psychopath thriller.
#
#
# Cluster #6 sentences (density score: 0.362):
#
# The story was well written but those damn characters pissed me off.
# Interesting plot but the characters were so unlikeable - ugh!
# There weren't any likeable characters in this book and that's why I liked it.
# It is wonderfully paced and a really well put together story, but I hated the main characters so, so much.
# I really wanted to like this book, but UGH both of the main characters were such horrible people.
# I didn't find either main character likable, which made it hard to be invested in how the story ends.
# On the other hand, however, all the characters were horrible and evil; I read characters more than I read plots and having such horrible characters just made me crazy.
# The characters are very unlikeable which made it hard to keep reading for any length of time, I just kept wanting to get away from them.
#
#
# Cluster #7 sentences (density score: 0.305):
#
# Well, this was a great read as far as me not wanting to put it down.
# It took me a while to get into it but after a while it was a compelling read.
# Loved it until the end, which was a bit disappointing.
# It wasn't bad at all, I just had a lot going on never got to a point where I couldn't put it down.
# Didn't see that coming, and I didn't like it.
# I put off reading because I didn't think I would like it.
# I thoroughly enjoyed it, it just wasn't as much of a page-turner the other ones were.
# I'd heard mixed reviews; some people thought the beginning was boring and had to put it down.
#
#
# Cluster #8 sentences (density score: 0.272):
#
# I cannot say too much about the plot other than it tells of a bad marriage, which becomes worse as the story unfolds, and the disappearance of the wife on the couple's 5th anniversary.
# That being said, it was a well written story of a truly messed up marriage.
# The book is basically a marriage that is a totally disaster.
# This story is from the point of view of a husband and wife, and it becomes very clear that there is something not quite right with this marriage.
# Rather, their relationship tells the story of a marriage's descent into utter depravity.
# The mystery takes a well-worn trope - did the husband kill his wife?
# Then when we get about half way through the book and we learn of the twist and its really a great twist, the wife is crazy and been plotting against his husband for a long time and seeing it unfold from each viewpoint as the story unfolds is cool.
# I enjoyed the alternating perspectives of the husband and wife that describe the wife's disappearance and circumstances leading up to it.
#
#
# Cluster #9 sentences (density score: 0.167):
#
# It's definitely not like anything I've ever read.
# That said, the last part of the book is a bit too much to swallow, but good fun all the way.
# I don't dare say much more as it gives away the plot line.
# It flowed well, even though it was just unwrapping one terrible thing after another.
# It's a good read, albeit entirely messed up.
# The ending is so absurd and preposterous which just makes it even worse that I read the whole thing.
# You have to get through some pages to really get sucked into this story.
# I can't believe I read the entire thing before anyone clued me in.
#
#
# Model density score: 0.36656

# %% [markdown]
# These results still look good! Let's try an even smaller sample.

# %%
# Get sentence clusters from a 99% review sample of our dataset
random.seed(24)
sentences, sentence_vectors = get_review_sample(gg_file_path, 0.01)
get_clusters(sentences, sentence_vectors, k=9, n=8)
# Out:
# This sample consists of 367 sentences from 82 reviews
#
# Cluster #1 sentences (density score: 0.51):
#
# Gillian Flynn is a beautiful writer.
# It's the third novel I've read by Gillian Flynn and it didn't disappoint.
# Very disturbing at time, but all Gillian Flynn books are.
# I would reccommend it to anyone i know and give major props to Gillian Flynn.
# Gillian Flynn won me over by tapping into my morbid curiosity.
# This is a sharp, witty and unpredictable book by Gillian Flynn.
# It also feels like Gillian Flynn asks the reader: how well do you know the book's characters?
# I admire Gillian Flynn for being bold enough to use this style of writing to tell her story.
#
#
# Cluster #2 sentences (density score: 0.468):
#
# Honestly I read this book since everyone else was raving about it.
# i was so excited to read this book!
# I cannot possibly say enough good things about this book!!
# This book had it all for me, including one of the best endings I have read in awhile.
# One of the best books I have read this year.
# The only thing which I found slightly disappointing about this book is the ending.
# This was a great book even with some awful main characters.
# Great book, just not AS good as the first two.
#
#
# Cluster #3 sentences (density score: 0.432):
#
# I liked the twists which made it a good fast read but the end was anticlimactic
# I am really disappointed in the ending, but the rest of the book was amazing.
# Found it very compelling, but was a touch disappointed with the ending - not as clever as the rest of the book had been I felt.
# The ending wasn't to my liking, but overall I enjoyed reading it.
# The ending was disappointing, and overall I just read this book because I wanted to know.
# The only thing which I found slightly disappointing about this book is the ending.
# I loved the first 200 pages and then was totally dissapointed by the ending .
# I was analyzing from word one, and although I had a good idea of what actually happened, the ending was still so full of twists and effed-up people that it didn't matter.
#
#
# Cluster #4 sentences (density score: 0.432):
#
# I can say the characters are well written, hugely unlikable, but well written.
# You, as the reader, think you have gauged the characters personalities and motives; and yet these same characters later appear out of character.
# Once, I adjusted and the story began to unfold, and in spite of the most unlikeable protagonists to ever be lead characters, I was hooked.
# The characters were so unlikeable,however i was intrigued enough to keep reading and it was something different.
# I love how the characters weren't as black and white as they seemed; it made for a great story.
# The writing was good, but these characters.
# The characters were not likeable or believable.
# I went through so many theories and changed my mind about the characters a hundred times.
#
#
# Cluster #5 sentences (density score: 0.418):
#
# I loved how the chapters jumped back and forth between Amy and Nick.
# In the first half i felt like i understood Amy completely and that Nick was a lying douchebag.
# I loved Nick, I loved Diary Amy, with all her quizzes.
# Nick's chapters are the day of Amy's disappearance leading up to the final day, and Amy's are diary entries from when she had first met Nick until they picked up and moved to Missouri.
# "Amazing Amy" was crazy yet often appeared very normal so you never knew which Amy was going to be presentthe ending was slightly blah but it leaves things open for another book.
# The tagline of this book is: 'There are two sides to every story', and you definitely feel conflicting emotions towards both Nick and Amy.
# Nick and Amy are totally crazy and, unfortunately, linked to each other forever, even if they're united by hatred of each other.
# It was haunting, it was clever, and i didn't know who i liked (or disliked) more, Amy or Nick.
#
#
# Cluster #6 sentences (density score: 0.379):
#
# The first part of the story progressed too slowly for me, but once you get past that it is a very quick read.
# I thoroughly enjoyed the first half of the book.
# After i got to the end of the first half and started the second half was when my interest was piqued and i started flying through the book completely immersed.
# Simply because the first half of the book felt so ordinary i almost put it down.
# I can honestly say this is the first book I DEVOURED in a very long time.
# Once it hit part two it was interesting and I could stand reading it.
# But even so I was eager to see how it played out, and read most of the book in one day, and really enjoyed it.
# I finished this book in the wee hours of this morning and always hated to put it down as I had to find out what happened.
#
#
# Cluster #7 sentences (density score: 0.314):
#
# On their fifth anniversary the wife goes missing and the husband (naturally) is accused.
# It's also a dark, interesting look on marriage.
# This is a sick and compelling story of marriage gone horribly awry.
# But no one really knows what was going on inside their marriage.
# Suffice it to say that it was 10% what I expected (a woman disappears on her 5th wedding anniversary and of course the husband is the one in the hot seat) and 90% completely surprising.
# The book kept making me analyze my own marriage.
# A woman goes missing from her home in Missouri on the day of her fifth wedding anniversary, shortly after the couple has moved from New York, leading police to suspect her husband.
# This novel poses the question: how well do you know your spouse?
#
#
# Cluster #8 sentences (density score: 0.298):
#
# It's hard to explain, other then that I enjoyed it.
# I just don't understand the end.
# I liked it, to an extent.
# I read this all in one sitting, i couldn't stop.
# I'd heard mixed reviews; some people thought the beginning was boring and had to put it down.
# I guess I still want to think it over!]
# In short I thought it was very good.
# I honestly thought it would end much differently.
#
#
# Cluster #9 sentences (density score: 0.272):
#
# I don't usually read thrillers, but this is a well-written mystery novel.
# Normally, I'm not a huge crime novel reader.
# I don't usually read crime type novels but this is definitely a thriller/crime novel - a bit of a whodunnit.
# It's refreshing to read something that isn't so formulaic.
# If you find it hard to read a book where the protagonists are unlikable, then this is NOT the book for you.
# Which is a good thing because as with all thriller/suspense novels, I have a hard time with the willing suspension of disbelief thing.
# Gone Girl is one of the best books I've read in awhile.
# This is probably the best written novel from a viewpoint from a "woman scorned" ever!
#
#
# Model density score: 0.39146

# %% [markdown]
# The model starts to break down a bit here, but these are still remarkably good results. From only 367 sentences our model was still able to pull out the same nine broad thematic clusters.
#
# Thus it seems that our model is able to perform quite well even on small datasets (assuming there are indeed patterns in the datasets to detect). We should not think that we need thousands and thousands of reviews in order to deploy our algorithm.
#
# ## Filtering reviews by rating
#
# Up until this point we have been running our model on (a random sample) of an entire dataset. But it is possible that our results would improve if we used our model to extract the most expressed opinions, not across *all* of a book's reviews, but only across its *positive* or *negative* reviews. Or we might simply be interested to know what people who liked some book are saying about it, or what people who didn't liked it are saying about it. Let us then see what happens when we filter our reviews by their rating.
#
# Let's first get a sense of the breakdown of our dataset.

# %%
pd.read_csv(gg_file_path)['rating'].value_counts().sort_index()
# Out:
# 0.0      413
# 1.0     1465
# 2.0     3457
# 3.0     8382
# 4.0    16194
# 5.0    11962
# Name: rating, dtype: int64

# %% [markdown]
# As we can see here, a strong majority of the reviews are positive, at 4 or 5 stars. This class imbalance is not necessarily an issue, however, since we know now that our model performs well on large and small datasets. Nonetheless, this may be something important to keep in mind as we proceed.
#
# Let us run our model on only the good reviews, which we will define as reviews with ratings of 4 or 5.

# %%
def filter_reviews(file_path, lower, upper):
    '''
    Function to filter reviews to those falling within a rating range
    '''
    
    # Read in file as dataframe
    df = pd.read_csv(file_path)
    
    # Filter dataframe to review ratings falling within specified range
    filtered_df = df[(df['rating'] >= lower) & (df['rating'] <= upper)].reset_index(drop=True)

    # Copy sentence column to new variable
    sentences = filtered_df['sentence'].copy()

    # Vectorize sentences
    sentence_vectors = embed(sentences)
    
    return sentences, sentence_vectors

# %%
# Get sentence clusters for 4-star and 5-star reviews
sentences, sentence_vectors = filter_reviews(gg_file_path, 4, 5)
get_clusters(sentences, sentence_vectors, k=9, n=8)
# Out:
# Cluster #1 sentences (density score: 0.543):
#
# I was kind of disappointed with the ending but it was a real ending.
# I wasn't a huge fan of the ending but at the same time, the ending made sense with the story.
# I did feel the ending was a little anti-climatic but I love that I didn't expect it.
# I liked the book, but the ending was not what I expected AT ALL!
# I didn't really love the ending though.
# I don't think I liked the ending, but I am still mulling it over.
# I really didn't care for the ending.
# I didn't like the ending at all.
#
#
# Cluster #2 sentences (density score: 0.474):
#
# Gillian Flynn is a good writer and she had me fooled.
# Gillian Flynn is an awesome writer.
# Gillian Flynn is a brilliant writer.
# I'm definitely going to be reading another Gillian Flynn book.
# Gillian Flynn is an amazing writer.
# I can't wait to read another book by Gillian Flynn.
# My favorite Gillian Flynn novel so far.
# I can't wait to read another book by Gillian Flynn-- it was so hard to put this one down!
#
#
# Cluster #3 sentences (density score: 0.441):
#
# I was so into this book but I honestly didnt understand the last chapter of the book!!!
# This book was great - I just couldn't put it down.
# Dont get me wrong i did enjoy reading this book very much.
# I've been wanting to read this book for a long time.
# This book is one of the best books I have read in a long time!
# This book was very well-written and one of the most interesting books I've ever read.
# I almost didn't read this book, I'd heard/read so much about it.
# I loved every second of reading this book.
#
#
# Cluster #4 sentences (density score: 0.386):
#
# Amy is married to Nick, and the book starts out with Amy going missing.
# How the story jumps between Nick and Amy's diary is fantastic at showing the present and the how Amy came up to being dead and resenting Nick.
# Nick was cheating on Amy for over a year and Amy had some secrets even Nick would have been shocked to find out!
# As far as characters go, I found both Nick and Amy to be absolutely fascinating.
# Still seems like there is more to tell of the Nick and Amy story.
# Nick and Amy's parents have plenty of possible suspects because people are always so obsessed with Amy.
# I loved the way the book goes back and forth between Amy and Nick.
# Both Nick and Amy tell the story, Nick as the narrator and Amy through her journals.
#
#
# Cluster #5 sentences (density score: 0.374):
#
# It was a very quick read and I enjoyed the twists in the plot.
# It is an amazing psychological thriller, very well written and full of plot twists and turns.
# Final thoughts   Gone Girl is a great novel, full of suspense and plot twists.
# I loved the plot twists and the unexpected turns in this tale.
# Well written, very suspenseful with many great plot twists.
# I highly recommend it to anyone who likes mysteries, thrillers, and completely unpredictable but believable twists and turns.
# The ending was not what I expected, but overall Gone Girl was a good book with a lot of unexpected twists and turns!
# It was a great psychological thriller full of unexpected twists and turns.
#
#
# Cluster #6 sentences (density score: 0.334):
#
# I loathed both of the main characters and yet loved the story.
# It is amazing how hard it is to write a positive review about a story in which I distinctly dislike both the main characters.
# I truly enjoyed the love-hate relationship that the reader has with the characters (although the same can be said for the characters themselves).
# Loved the story, but the characters drove me crazy.
# Book was well written and engrossing, but I disliked both main characters so much, it was hard to care about what happened to them.
# It is wonderfully paced and a really well put together story, but I hated the main characters so, so much.
# I was involved in the characters' stories from the first page and, even though there are really no likable characters, I had to know what happened next.
# Could not put this down and totally got caught up in the story, which is amazing, considering I really didn't like the main characters.
#
#
# Cluster #7 sentences (density score: 0.297):
#
# I was definitely shocked over and over while reading, right up to the end.
# It kept me reading later than I should have but I was kinda disappointed in the end.
# I loved it until the end which I found to be disappointing.
# I knew it was going to be twisted, but this was way out there compared to what I'm used to reading.
# I probably would have enjoyed it more if I hadn't heard so much about it before reading.
# While reading, I didn't see how it could go downhill, but it really had.
# I thought perhaps it dragged on just a bit in the end, but ultimately was an excellent read.
# Like most people, I thought the end was a bit of a let down.
#
#
# Cluster #8 sentences (density score: 0.274):
#
# I cannot say too much about the plot other than it tells of a bad marriage, which becomes worse as the story unfolds, and the disappearance of the wife on the couple's 5th anniversary.
# Deliciously nasty novel about a husband and wife who truly hate each other; when the wife ends up missing, who's to blame?
# Most people are familiar with the premise, marriage gone bad, wife disappears, and the husband is the main suspect of foul play.
# This story is from the point of view of a husband and wife, and it becomes very clear that there is something not quite right with this marriage.
# This is a very well-written and creepy story about a completely dysfunctional marriage and the extreme lengths to which Amy Dunne goes to get the upper hand over her husband, Nick.
# A thriller about a twisted marriage, told in a suspenseful way, with carefully-designed sudden reversals that change how you view the husband and the wife.
# A tale about a TRUE bad romance starting with the disappearance of a wife with the husband being the number one suspect-something we hear about almost daily.
# This is a story of a marriage gone terribly wrong, where, on the couple's 5th anniversary, the wife just disappears.
#
#
# Cluster #9 sentences (density score: 0.157):
#
# Well, that's one of the most messed up things I've read in a long, long, while.
# I'm pretty sure I hate it, but it might just be brilliant.
# It was so disturbingly messed up in a wonderful "I need to keep reading" type of way!
# Right away you know there's something twisted going on and you can't help but be intrigued.
# That said, it's a deeply weird story.
# Just when you think you have it figured out another twist gets thrown in.
# I'd like to say more but don't want to ruin the story for anyone.
# It's got a great plot, but that's not the best part.
#
#
# Model density score: 0.36425

# %% [markdown]
# These results look very similar to what we observed in our earlier trials on the unfiltered dataset. So it seems that the general trends we observed in the dataset are well represented in the good reviews. Let's see if things change when we filter to only the bad reviews.

# %%
# Get sentence clusters for 1-star and 2-star reviews
sentences, sentence_vectors = filter_reviews(gg_file_path, 1, 2)
get_clusters(sentences, sentence_vectors, k=9, n=8)
# Out:
# Cluster #1 sentences (density score: 0.504):
#
# I really didn't like this book.
# I wasn't a fan of this book.
# I didn't really like this book.
# I really, really wanted to like this book.
# Aside from the easy read, I really didn't like this book.
# I thought this book was going to be good, I really did.
# I really really wanted to love this book.
# I really wanted to like this book.
#
#
# Cluster #2 sentences (density score: 0.496):
#
# I thought the ending was AWFUL.
# The ending was a total anti-climax - I see the intention of the ending but it irritated me.
# I really did not like the ending.
# I found the ending so very unsatisfying.
# Brilliant, but I hated the ending!
# I wanted to like it more but the ending really disappointed me.
# The only good thing about the ending was that it was over.
# It was an interesting book but I really hated the ending.
#
#
# Cluster #3 sentences (density score: 0.425):
#
# Interesting plot but the characters were so unlikeable - ugh!
# Not one of the characters was likeable at all.
# I completely hated the main characters.
# I really disliked this book because I really REALLY hated the main characters.
# I really wanted to like this book, but UGH both of the main characters were such horrible people.
# I just didn't like the characters.
# I didn't like ANY of the characters.
# I didn't care about any of the characters.
#
#
# Cluster #4 sentences (density score: 0.423):
#
# Let's start with the fact that Gillian Flynn is an excellent writer.
# Gillian Flynn is a very talented writer, but this book just didn't do it for me.
# Gillian Flynn is clearly a talented writer.
# Gillian Flynn is a good writer.
# I won't be reading anything by Gillian Flynn again.
# It's better plotted than written, and I'll not be rushing to read anything else written by Gillian Flynn.
# I had read another Gillian Flynn and disliked the characters so much I thought, never again.
# It will most likely be the last Gillian Flynn book I read.
#
#
# Cluster #5 sentences (density score: 0.391):
#
# I've never been so compelled to read a book so quickly that I truly disliked.
# I finished the book because I was somewhat interested in the outcome but it took me a while to read because I could not get "sucked in".
# I read it for book club, so I felt compelled to finish, but it was painful.
# I almost stopped reading it entirely but I like to finish any book I start.
# I felt the first half of the book dragged to the point that I wanted to give up reading it.
# I went into reading this with zero expectations (I didn't really know much about the book or the actual plot) and as I started to read, I was excited that I would end up loving it upon finishing it.
# So, while a well written book, in the end it just wasn't a book I liked.
# I thought the book (what I read of it, that is) was interesting and well-written.
#
#
# Cluster #6 sentences (density score: 0.387):
#
# I couldn't figure out if Nick had really killed Amy.
# I hate nick even more after finding out what he's done to Amy!
# I hate how self involved nick is and how dumb Amy is.
# I just couldn't stand the kind of people Nick and Amy were.
# I'm not sure if I was supposed to like Amy at the beginning and feel sorry for Nick at times, but I didn't.
# Nick isn't actually the crazy one, it's really Amy.
# I just don't give a damn about Nick and Amy.
# I no longer cared about either Amy or Nick, and the characters really drive the story.
#
#
# Cluster #7 sentences (density score: 0.373):
#
# The plot has so many twists and turns in it that I felt it was a little hard to keep up and defantly hard to figure out the ending, which I do in a murder mystery novel.
# The story had a lot of twists and turns, but at time it falls short of me wanting to finish this book.
# Gone Girl did entice me to guess once and awhile about the ending so it kept me at the edge of my seat for a bit, but elements of the plot were predictable.
# the plot was kind of predictable in parts, of found the writing to be poor at times and I just couldn't not enjoy this story at all.
# The characters were unlikeable, the plot unconvincing and the final twist made me wonder why I had bothered to read it to the end.
# I really wanted to get into this book, and I am sure if I would've stuck it out there would've been some shocking plot twists.
# I didn't really find the plot twists all that surprising given the foreshadowing.
# I liked the book most of the time, cos it was different than the Thrillers I've read before, some other perspective, but the ending ruined it for me
#
#
# Cluster #8 sentences (density score: 0.271):
#
# Too bad, because I mostly enjoyed it.
# I don't know what it was, just too out there and not in a good way.
# Didn't see that coming, and I didn't like it.
# I was hoping that it would at least be a decent read.
# I liked that it wasn't as predictable as I thought it would be.
# I couldn't even read the entire thing I hated it so much.
# I'm not convinced, and rather "meh" about the whole thing.
# Actually, I felt a lot let down.
#
#
# Cluster #9 sentences (density score: 0.174):
#
# Well the two main characters of this twisted story are certainly miserable people who deserve each other.
# Totally preposterous storyline, especially at the end, because who would want their child to be treated by a psycho mad woman????
# This is a very readable but sour story about an awful married couple, both rather nasty, selfish and superior but she's also a bit of a psychopath.
# When one character is a psycho and the other is just majorly unlikeable it does not make for a fun read.
# This is a messed up book about two really screwed up people and the ending just made me really mad.
# It just becomes more sad to see how crazy this married couple who are supposed to be in love mistake it and it becomes possession.
# I guess there are plenty of people out there who don't mind authors dragging them through the emotional mud and leaving them feeling terrible after reading a book, but I am not one of them.
# Though I will grudingly admit the plot was brilliant and it was nice reading about a woman who dosen't get killed but one-ups her husband.
#
#
# Model density score: 0.38279

# %% [markdown]
# Here (for once!) our clusters look quite different. Some of the themes are the same as before, but many are quite different. To summarize:
#
# 1. Didn't like the book
# 1. Disliked the ending
# 1. Disliked the characters
# 1. Gillian Flynn is an excellent writer
# 1. Read it just to finish it
# 1. Main characters (Nick and Amy)
# 1. Plot twists & turns
# 1. Didn't match expectations
# 1. Horrible characters
#
# Interestingly, although these clusters are different from what we see before, they don't actually add much new information to what we already knew. Rather, these clusters simplify the sentiments in our previous results: rather than seeing that people loved the story despite disliking the ending, here we see simply that people disliked the ending. The only truly new sentiments captured here are generic ones: that the book didn't match expectations, and that people simply didn't like the book.
#
# Because of this, it does not seem to benefit our model to filter reviews by their rating. The important sentiments are still likely to be captured in the full set of reviews, and the full set is more likely to capture more complex sentiments.
#
# Nonetheless, from a user experience perspective, it may still make sense to allow the user the option of filtering reviews by rating, in case they are particularly interested in seeing what people who loved or hated a book are saying about it. The important conclusion for now is that filtering shouldn't be the *default* option, as the best results seem to be achieved when no filtering is done.
#
# ## Testing our conclusions
#
# So far we have been basing all of our conclusions on a single dataset. It is obviously not guaranteed that these results will generalize to other datasets. So let's see how our model actually performs on some different and smaller datasets. We'll be begin with a dataset for Margaret Atwood's *The Testaments* that was scraped from GoodReads in May 2020.

# %%
ts_file_path = 'data/42975172_the_testaments.csv'

sentences, sentence_vectors = load_sentences(ts_file_path)

pd.read_csv(ts_file_path)['rating'].value_counts().sort_index()
# Out:
# This dataset consists of 11289 sentences from 1198 reviews
# 1.0    1393
# 2.0    2288
# 3.0    2533
# 4.0    2409
# 5.0    2666
# Name: rating, dtype: int64

# %% [markdown]
# As we can see here, this dataset is much smaller than the *Gone Girl* dataset, with about one fourth the number of sentences and reviews. Furthermore, this dataset is much more balanced with respect to its ratings. (This is due in part to how the data was collected.) Let's see how our model does on the full dataset with 8 clusters.

# %%
get_clusters(sentences, sentence_vectors, k=8, n=8)
# Out:
# Cluster #1 sentences (density score: 0.516):
#
# As a fan of the book The Handmaid's Tale and an even bigger fan of the television series The Handmaid's Tale, I was very excited for this novel.
# I loved the handmaids tale but didn’t like this at all.
# First, the handmaids tale is one of my all time favorite books.
# I’ve read The Handmaid’s Tale, more than once, and I genuinely enjoyed it.
# ‘The handmaid’s tale’ was one of the best books I’ve ever read.
# I'm glad I read it, but I think The Handmaid's Tale is a better story.
# I feel like this novel just cheapened the Handmaid’s Tale, which is such a shame.
# I absolutely loved The Handmaid’s Tale.
#
#
# Cluster #2 sentences (density score: 0.449):
#
# I did like learning more about Aunt Lydia and how she became the infamous Aunt Lydia.
# Also, the only interesting character in the book is Aunt Lydia.
# Aunt Lydia is the most compelling but even she can't save this book.
# Aunt Lydia was the sole reason I read this book until the end.
# The only good I found in the entire book was the storyline of Aunt Lydia and a couple of the other Aunt's.
# Ann Dowd (Hulu’s Aunt Lydia) reading the part of Aunt Lydia is truly a thing of beauty.
# The stories behind Agnes choosing to become an Aunt, Aunt Lydia bringing the downfall of Gilead, and Jade's identity were interesting.
# I really enjoyed the Aunt Lydia parts of the novel.
#
#
# Cluster #3 sentences (density score: 0.393):
#
# I really didn’t enjoy this book.
# I had high expectations but I feel like this book completely ruined the mystery of the first book.
# I really didn’t care for this book, in fact I didn’t even finish it.
# 5*]To be honest, there isn't much I can say about this book apart from that it is a good read but a book that didn't need to be.
# I think this book just wasn’t for me.
# I thought this book was going to be different than it was.
# The only truly good thing about this book is that it was a fast, easy read.
# I am still going to try to read the book, because I am not a huge fan of listening to a book.
#
#
# Cluster #4 sentences (density score: 0.344):
#
# Margaret Atwood is still a talented writer and this isn't a bad book.
# Atwood is a wonderful writer and I've yet to read anything of hers I didn't find worthwhile, but I didn't think The Handmaid's Tale was a book that needed a sequel.
# Margaret Atwood is one of my favourite writers so that was never in doubt.
# I love Margaret Atwood and I was very excited to read this but felt let down by the end of the book.
# I never thought I would be so underwhelmed by a Margaret Atwood book, but this story feels so unnecessary.
# )I could go on, but this is about ‘The Testaments,’ so suffice it to say that after ‘The Handmaid’s Tale,’ I developed more than just an appreciation for Margaret Atwood as a writer, but an ongoing relationship with her work.
# I still do not grasp this; it felt like Atwood wanted to include some suspense in her book; making it a page turner instead of a literary materpiece!
# )The thing is, Atwood wasn't trying to write another Handmaid's Tale.
#
#
# Cluster #5 sentences (density score: 0.313):
#
# It was a GREAT read in and of itself, with plot twists, intriguing characters and a lot of Giledean insight - but could in no way compare to its predecessor.
# I found the characters poorly drawn, parts of the plot unbelievable and was rather bored and underwhelmed by the narrative and the book as a whole.
# I wouldn't say that this was as deep and impactful as the first book, but it was still a beautiful story and I found the plot a lot more enjoyable.
# Even though there were chapters that didn’t add much to the characterisation or the world, and even though the story was predictable and not as compelling as the first book, I have to say that I loved Margaret Atwood’s writing.
# The narrative is surprisingly simple, the plotline kind of predictable and hopeful, and the characters good enough though a lesser of them would have been better.
# There were several aspects of the plot that were predictable, but the first half of the book was still so interesting and I couldn't wait to find out how everything would come together.
# The second thing is the story itself: I found all major plot points and twists rather foreseeable and at most mildly interesting.
# Even though the actually story-telling is pretty good and I did enjoy it, it just feels like a story that didn't really need to be told.
#
#
# Cluster #6 sentences (density score: 0.275):
#
# It was a quick read, even if by the end I was just trying to get it over with.
# I kept telling myself I liked it but underneath something was a bit off.
# I'm not sure I've ever been so disappointed by a book.
# I just finished ´The Testaments` and didn’t love it as much as I hoped I would.
# Disappointing, didn't really hold me, I've definitely read better.
# Had I read it on its own, I don't think I would have enjoyed it as much.
# I really did want to like this, but I just didn’t really see the point of this book, even after persisting with it and finishing it.
# For some reason I wasn't super excited to read this, and then it BLEW MY MIND OFF.
#
#
# Cluster #7 sentences (density score: 0.219):
#
# listen, nothing could ever recreate the handmaid's tale and this book doesn't try to, but it does develop gilead and the logic behind it and the roles people play within its warped society into a much bigger picture than offred could provide.
# As we’ve only ever heard of Gilead from a Handmaid’s perspective, it was wonderful to see how children in Gilead are indoctrinated into believing in the regime, and also to understand how things were run from Aunt Lydia’s high (for a woman) position within the system.
# The Testaments is most refreshing in that it’s not about men at all; they get less play than they did in The Handmaid’s Tale and, outside of one major character, the book doesn’t really concern itself with them.
# As Atwood unfolds The Testaments, she opens up the innermost workings of Gilead as each woman is forced to come to terms with who she is, and how far she will go for what she believes.
# while this sequel also (rightly) calls out todays society for the oppression of women, it feels like the narrative is telling me what to think, where ‘the handmaids tale’ forced me to come to my own conclusions.
# The Handmaid's Tale talks about a women's culture that was elusive before Gilead and is now a necessity in that reality.
# The Testaments overall feels like Atwood taking back control of the dystopia she created three decades ago and skillfully weaving a narrative in a way only she can.
# One of the most horrifying themes of the The Handmaid’s Tale, is how passive (and at times complicit) Offred could be as events unfolded; she is an inherently reactionary character.
#
#
# Cluster #8 sentences (density score: 0.129):
#
# I'm not sure I've ever been so disappointed by a book.
# The only good thing that happens in this fucking book is it ends.
# The plot doesn't make any sense anymore.
# There isn't much to say about the plot other than it was borderline ridiculous.
# Worst of all, it isn't even well-written.
# That's as may be, but it doesn't make for a very compelling novel.
# This wasn't quite as bad, but it added nothing to The Handmaid's Tale.
# This might just be the most disappointing book I’ve ever read.
#
#
# Model density score: 0.32964

# %% [markdown]
# Judging from these results, our model has done a good enough job of clustering together semantically similar sentences (though not as good as it seemed to do with *Gone Girl*). However, these sentence clusters seem much less revealing of the book itself. Some clusters seem to merely express a simple sentiment of 'I didn't like it' or 'I was disappointed'; other clusters seem simply to be picking up a shared proper name, like 'Margaret Atwood' or 'Aunt Lydia' or 'The Handmaid's Tale'. On the whole, these clusters just don't tell us a whole lot about what is actually good or bad about the book.
#
# Now this doesn't necessarily any issue with our model. The issue could very well in the data itself; perhaps reviewers of *The Testaments* just aren't saying many specific things about the book. But given the distribution of the review ratings, it may behoove us to filter the reviews and see if more meaningful clusters emerge when we look only at people who like or didn't like the book.

# %%
# Get sentence clusters for good reviews
sentences, sentence_vectors = filter_reviews(ts_file_path, 4, 5)
get_clusters(sentences, sentence_vectors, k=6, n=8)
# Out:
# Cluster #1 sentences (density score: 0.493):
#
# The sequel to The Handmaid’s Tale is written very different from Margaret Atwood’s dystopian classic, but in no way does it suffer as a follow-up.
# I loved "The Handmaids Tale" and starting this book, I wasn't so sure how to feel.
# I’m the reader that loved The handmaid’s Tale and never thought about a follow up book.
# The Handmaid's Tale has been one of my favourite novels for decades, and there was a lot for this sequel to live up to.
# I haven’t read “The Handmaid’s Tale”, but I am a big fan of the series.
# I'm not going to spend too much time on The Testaments, Margaret Atwood's follow-up to The Handmaid's Tale.
# I do not see the The Testament by Margaret Atwood as a sequel for The Handmaid's Tale.
# I read The Handmaid's Tale about 15 years ago and adored it.
#
#
# Cluster #2 sentences (density score: 0.452):
#
# I did like learning more about Aunt Lydia and how she became the infamous Aunt Lydia.
# Ann Dowd (Hulu’s Aunt Lydia) reading the part of Aunt Lydia is truly a thing of beauty.
# Aunt Lydia took a back seat to the two girls, who lacked the life experience that made Aunt Lydia so fascinating.
# Speaking of which, you likely already know that Aunt Lydia is one of the three narrators--yes, that Aunt Lydia.
# I really enjoyed the Aunt Lydia parts of the novel.
# The interesting narrator in The Testaments is Aunt Lydia; she is complex, calculating, and surprising, and reveals a lot about how she became Aunt Lydia—and the story is not the same as in the series.
# Weirdly it felt like fanfic of the TV series The Handmaid’s Tale; Atwood has said she was inspired by Ann Dowd’s performance as Aunt Lydia, and of course I was imagining Dowd as Aunt Lydia here.
# Aunt Lydia becomes a much more three-dimensional and in some respects sympathetic character, as we learn some of her backstory and her real views on what goes on in Gilead.
#
#
# Cluster #3 sentences (density score: 0.358):
#
# However, I really did love this book - it was a super enjoyable read.
# Like so many other readers, I loved this book, but for reasons I didn't expect.
# I know there have been mixed reviews on this book but I really liked it.
# Yet, I enjoyed the heck out of this book.
# I wouldn't say that this was as deep and impactful as the first book, but it was still a beautiful story and I found the plot a lot more enjoyable.
# I enjoyed reading the book, but I guess it was not even close to Handmaid's tale in terms of quality.
# That said, I enjoyed this book though there are some issues that I'll quibble about.
# My thoughts:It was good; I liked it much more than the first book.
#
#
# Cluster #4 sentences (density score: 0.289):
#
# I definitely think Aunt Lydia's chapters were the most interesting, and her voice definitely seems more a continuation of the Handmaids Tale in terms of the feelings evoked and the writing style.
# There are a couple of details created by fans and TV writers that have made their way into the book, but it’s clear that this is Atwood’s world and only she gets to decide what ultimately happens in it.
# A great part of the delight of this novel is in seeing what Atwood decides to do with the story, so I'll spare anybody who hasn't read it yet to discover that themselves.
# So although this sequel doesn't quite live up to the first book for me, I think it allows readers to return to Gilead in a new and different way, and it's an interesting continuation of a story that I think still serves as a warning to us all.
# I think Margaret Atwood did such a great job thinking through the story and showing a completely different perspective of Gilead.
# I do feel that leaving so many questions unanswered was a big strength of the Handmaids Tale, and it made the story have so much more impact, so although I enjoyed this sequel and found the plot progression interesting, I'm not convinced it was wholly necessary.
# Margaret Atwood’s brilliance as a storyteller is on full display and readers will not be disappointed to discover where she picks up after leaving us with so many questions at the end of The Handmaid’s Tale.
# Even though there were chapters that didn’t add much to the characterisation or the world, and even though the story was predictable and not as compelling as the first book, I have to say that I loved Margaret Atwood’s writing.
#
#
# Cluster #5 sentences (density score: 0.193):
#
# As we’ve only ever heard of Gilead from a Handmaid’s perspective, it was wonderful to see how children in Gilead are indoctrinated into believing in the regime, and also to understand how things were run from Aunt Lydia’s high (for a woman) position within the system.
# She accepts the social structure as the way things are supposed to be, because that's all she's known, and being from a Commander's family, she's grown up with privileges and in as much safety as any female in Gilead could have.
# One teenage girl, Agnes grows up in Gilead and is a woman who is supposed to submit to her role as a women without right.
# Being brought up in Gilead ever since she was a child, she fails to recognize its bad side.
# As Atwood unfolds The Testaments, she opens up the innermost workings of Gilead as each woman is forced to come to terms with who she is, and how far she will go for what she believes.
# The Testaments is most refreshing in that it’s not about men at all; they get less play than they did in The Handmaid’s Tale and, outside of one major character, the book doesn’t really concern itself with them.
# People going about their everyday lives while the horrors of Gilead are inflicted on countless women.
# listen, nothing could ever recreate the handmaid's tale and this book doesn't try to, but it does develop gilead and the logic behind it and the roles people play within its warped society into a much bigger picture than offred could provide.
#
#
# Cluster #6 sentences (density score: 0.174):
#
# IT MIGHT NOT BE WHAT I EXPECTED BUT I ENJOYED IT ALL THE SAME!
# While I did really like the book, there is just a lot wrong with it that bothers me.
# I think this was a MUCH more interesting read than the first.
# Don't throw things at me, but I might have enjoyed this even more than the Handmaid's Tale.
# I think I liked it more as well!
# Up until a few days ago I wasn’t even sure if I was going to read it.
# For some reason I wasn't super excited to read this, and then it BLEW MY MIND OFF.
# I cannot even gather my thoughts on this magnificent book.
#
#
# Model density score: 0.32655

# %%
# Get sentence clusters for bad reviews
sentences, sentence_vectors = filter_reviews(ts_file_path, 1, 2)
get_clusters(sentences, sentence_vectors, k=6, n=8)
# Out:
# Cluster #1 sentences (density score: 0.502):
#
# I loved the handmaids tale but didn’t like this at all.
# I feel like this novel just cheapened the Handmaid’s Tale, which is such a shame.
# As a fan of the book The Handmaid's Tale and an even bigger fan of the television series The Handmaid's Tale, I was very excited for this novel.
# I had extremely high hopes for this book given the fact that Margaret Atwood’s “The Handmaid’s Tale” is a modern-day classic.
# I loved The Handmaids Tale, but this just seems so bad?
# buddy read with NkishaI freely admit I'm not exactly a Margaret Atwood fan and when I decided to read this sequel to The Handmaid's Tale I doubted I would much enjoy it as I found The Handmaid's Tale to be less than well executed; marvellous premise though.
# ‘The handmaid’s tale’ was one of the best books I’ve ever read.
# I’ve read The Handmaid’s Tale, more than once, and I genuinely enjoyed it.
#
#
# Cluster #2 sentences (density score: 0.415):
#
# The only good I found in the entire book was the storyline of Aunt Lydia and a couple of the other Aunt's.
# Aunt Lydia is the most compelling but even she can't save this book.
# Aunt Lydia was the sole reason I read this book until the end.
# Aunt Lydia turns out to have both a surprising pre-Gilead backstory as well as a secret life as an “Aunt,” although there are no hints of these in any previous works.
# I read in another review that had the story been told by just Aunt Lydia it would have been better.
# The best parts were from the point of view of Aunt Lydia, some reasonably well written, but still full of clichés.
# Aunt Lydia had a stronger storyline but I think some of my opinion of her character is linked to the TV show.
# If the whole novel was written about Aunt Lydia, maybe Atwood would have made her journey more convincing, but alas.
#
#
# Cluster #3 sentences (density score: 0.409):
#
# I really didn’t enjoy this book.
# I really didn’t care for this book, in fact I didn’t even finish it.
# I had high expectations but I feel like this book completely ruined the mystery of the first book.
# Honestly this book is such a disappointment.
# I’m so so so let down with this book that I can’t even finish it.
# I didn't like this book at all.
# I didn't like this book at all.
# I’m so disappointed by this book.
#
#
# Cluster #4 sentences (density score: 0.316):
#
# I found the characters poorly drawn, parts of the plot unbelievable and was rather bored and underwhelmed by the narrative and the book as a whole.
# By the time the novel was done, the plot had reduced what started off as a strong book into something much less compelling than either the original book or the show.
# Still, the plot here is so thoroughly contrived and amateurish that I can barely believe the same author wrote both books.
# This is badly written, with paper-thin characters, no character development and a frankly, ridiculous plot, that is so far fetched as to be nonsensical.
# Had the story only been told in the POV of the two young girls, I honestly don’t think I could have finished this book, as their parts of the story fell completely flat and teetered on the verge of downright stupid (absolutely zero character depth).
# The plot is rushed (though I was looking forward to it being finished) and the prose isn't nearly as evocative as Handmaid's.
# Such a disappointment and in comparison to the handmaids tale, the writing was atrocious and read more like a YA novel.
# This was a mess of cliches and predictable plot points, and it very much reads like a book meant for teens.
#
#
# Cluster #5 sentences (density score: 0.249):
#
# I'm not sure I've ever been so disappointed by a book.
# Very disappointed but this one just wasn’t for me.
# I kept telling myself I liked it but underneath something was a bit off.
# It wasn't bad, but I didn't enjoy it, and I really think it wasn't needed.
# I wouldn't say that it was bad but it didn't really add much that.
# It just didn’t live up to my expectations and I didn’t want to read any further.
# It just seemed to be an anti-climax for me at the end.
# I applaud those who are enjoying it; it was a drastic disappointment for me.
#
#
# Cluster #6 sentences (density score: 0.16):
#
# The Handmaid's Tale was badly written, but it's as though she didn't even try here.
# As one reviewer wrote- we would have been better off left to wonder and imagine what happened to Gilead, and perhaps that was even the brilliance of Handmaid’s Tale, than to be left with this.
# I realize that you are seeing things from her perspective instead of from the people she's oppressed, but it didn't make sense for her to secretly be the hero.
# It's obvious that Atwood has never had the misfortune of enduring the repercussions of a family/friend suicide, but authors of her standing should really be more careful in their storylines.
# This wasn't quite as bad, but it added nothing to The Handmaid's Tale.
# The other issue that plagued The Testaments is that it just wasn't shocking like Handmaid's was back in the late 80's.
# Honestly, that's a bigger dystopia than the flimsy, paper-thin version of Gilead offered in this story.
# Honestly, that's a bigger dystopia than the flimsy, paper-thin version of Gilead offered in this story.
#
#
# Model density score: 0.34182

# %% [markdown]
# These results seem better. We're now getting more detail about why people liked or disliked the book. So perhaps our earlier conclusions about review filtering were mistaken. With a dataset that is more balanced between positive and negative reviews, filtering by review rating can reveal more meaningful results. This seems like further reason to include this as an optional parameter in our model, that the user can set as they wish.
#
# Let's see how our model performs on some other books. Here's how it does with Tara Westover's *Educated*, whose dataset was also scraped from GoodReads.

# %%
ed_file_path = 'data/35133922_educated.csv'

sentences, sentence_vectors = load_sentences(ed_file_path)
# Out:
# This dataset consists of 15369 sentences from 1265 reviews

# %%
# Get sentence clusters
get_clusters(sentences, sentence_vectors, k=8, n=8)
# Out:
# Cluster #1 sentences (density score: 0.394):
#
# Finally I think it is a book about Mormons even when she states at the start: “This story is not about Mormonism”
# She is clear as she meets many other Mormons at BYU that their Mormonism is not what her family is about.
# Tara's parents were Mormon, but as Tara states in the author's note, this story is not about or against Mormonism.
# At the very start of the book she claims it is not a book about Mormonism, but she allows the reader to assume that many of the quirky things her parents did, they did because they were Mormon.
# Her parents are members of the Church of Jesus Christ of Latter-day Saints, but they espouse views and beliefs that are very extreme; their practice of Mormonism looks nothing like the type of mainstream Mormonism I practice.
# It may have been what her family believed, but its not what the mainstream LDS church teaches.
# I know this book "wasn't about Mormonism" but it certainly leads credence to the cries of poor homeschooling families out there, as well as the backwater medicine practices, and, yes, Mormonism.
# Sure, they're Mormon, but for someone who's done a PhD on the history of Mormons and family structure Westover is piss-poor at explaining why any woman would buy into her own subjection in this particular way.
#
#
# Cluster #2 sentences (density score: 0.37):
#
# I disliked this book probably more than just about any book I have ever read.
# The book read like fiction, and I think that's why I didn't love the whole book.
# I couldn’t stop reading this book.
# I’ve heard so much about this book and was very eager to read it.
# I should start this by saying I'm not the biggest memoir reader- so memoirs are not typically my thing (so I'm not too surprised that this just wasn't the book for me).
# This is a good book I just wasn’t super compelled by the story.
# The more I read of this book, the less I liked it.
# The only reason I continued to read the book was because sooo many raved about how great this book was.
#
#
# Cluster #3 sentences (density score: 0.367):
#
# I believe Tara went through what she went through and honestly cannot even fathom all the awfulness that was her life.
# I thought it was amazing that Tara made it out of that family.
# Tara still has a lot to work through and I think this book was her attempt at that.
# Tara is nothing like her family.
# More than anything else, this book feels like Tara Westover's setting the record straight for her family and small community.
# This book has been heavily reviewed, so I will make a few observations:A difference between Tara (who eventually breaks free) and her sister-in-law (who doesn’t) is that Tara goes to great lengths to hide (to others and to herself) her shame.
# Tara does such an amazing job of telling her story.
# Tara Westover has no doubt faced unbelievable circumstances and has overcome them with incredible fortitude, but in writing such a personal story in such an academic style, one can’t help but feel distant from Tara.
#
#
# Cluster #4 sentences (density score: 0.306):
#
# Her re-telling of countless acts of abuse by her brother and mental abuse by her parents became redundant to say the least.
# Emotional and physical, Tara's story is most impressive that not only did she break out and get an education, but she escaped the abuse from her father and brother that kept all the rest of her family in check.
# These were abusive on their own, but an important part of the abuse Westover experienced came from her family's twisting of the truth to match her father's and brother's stories.
# She is estranged from most of her family because of her emotionally manipulative father and her physically abusive brother.
# I can't imagine living a life in the ways she endured between physical and emotional and mental abuse from her family.
# Tara not only suffered mental abuse from her parents but physical abuse from her brother, which was totally ignored by everyone around her.
# While she certainly has crafted an interesting story of abuse and religious extremism, she never made me feel anything other than horror of the abuse in her situation and hatred of her brother and father.
# That her sister, uneducated, dependent economically and emotionally on her other family members, alone in many ways, took the enormous, brave step of admitting to the author the abuse they had both suffered?
#
#
# Cluster #5 sentences (density score: 0.277):
#
# It seems clear to me that she simply must have received more schooling than she claims and was a gifted student; she certainly took a nontraditional path to university, but no one gets to a Cambridge PhD without some measure of privilege and education throughout their life.
# Finally, for a book titled 'Educated' and billed as being about how a girl went from a home school survivalist family to a PhD from Cambridge, I expected the story to be about her 'rags to riches' education.
# Westover, almost unbelievably—I had to finally google her to make sure she really was who she says she was!—not only graduated from BYU, but went on to graduate with a PhD in History from Cambridge, becoming truly “educated” about herself, her family, and the world.
# She was homeschooled (sort of) and raised in a household where a women’s place was in the home and history books were not to be trusted, yet she somehow makes her way to BYU, and then Cambridge where she earns a PhD in history.
# She is so inspiring that she was able to go from no formal education to getting one of the top scholarships in the world.
# In terms of the educational aspect, I believe it to be completely implausible that along with 2 of her siblings they were able to get Doctorate degrees with basically no home schooling.
# Many readers seem to be stuck here: how could have Westover graduated with a PhD from Harvard is she had absolutely no formal schooling until she was 17 and only one encyclopedia in the house?
# She’s incredibly gifted and despite never attending school, she taught herself well enough to go to University.
#
#
# Cluster #6 sentences (density score: 0.275):
#
# It is absolutely incredible she was able to get out of that situation and educate herself as much as she has.
# She is still doubting herself and her memories about what really happened and whether it was really as bad as she thinks.
# It sounds like she is still trying to process what happened and I hope she gained some solace from writing about her experiences.
# Quite frankly, most of her memories simply weren’t substantiated by her own story.
# I am reluctant to say more as this is her story and she can tell it how she chooses but I am not a fan of the narrative she portrayed.
# I admire that she actually admits that she doesn't remember certain events the same way as others she spoke with while writing the book.
# No matter what Westover does in the future, I’m glad she’s told her coming-of-age story.
# Her story is hard to believe, but her skill at relating it - and her cogent self-analysis - makes this an unforgettable memoir.
#
#
# Cluster #7 sentences (density score: 0.247):
#
# I still found it very unpleasant to read.
# It reminded me that I don’t like reading memoirs, but the whole thing just bugged me.
# I dunno, it was just getting to be a bit much for me to believe.
# Oh well, at least it was a quick read.
# I just couldn’t get into this story for whatever reason.
# I didn't enjoy this at all, and I believed even less of it.
# I was excited to read this because I'd heard so many good things.
# But it was an interesting read, no doubt about it, and it left me wondering about a lot of things.
#
#
# Cluster #8 sentences (density score: 0.126):
#
# I grew up in an extremely religious family and mostly cut them out of my life for over a decade because everything they believed was bad for me.
# I think being a part of a religious fundamental family would be tough and things would feel exaggerated and when you see a world and life so different from your own.
# I don’t even know how to describe it other than gut wrenching to see the effects on this family of neglect in the name of religious beliefs and in reality mental illness.
# I definitely know there are those people who are way out there in their beliefs and that some people truly do live horrific, cringe-worthy lives.
# The story is in fact so insane, that some people have chosen not to believe it.
# I never knew some people intentionally choose to live that way.
# Maybe because I grew up around some people who did some crazy things in the name of religion or were radically anti- medical establishment, this was not as astonishing to me as maybe to other people.
# The abuse and just ridiculous circumstances almost seem fictional, but sadly are true for too many people.
#
#
# Model density score: 0.29536

# %%
# Get sentence clusters for good reviews
sentences, sentence_vectors = filter_reviews(ed_file_path, 4, 5)
get_clusters(sentences, sentence_vectors, k=6, n=8)
# Out:
# Cluster #1 sentences (density score: 0.368):
#
# More than anything else, this book feels like Tara Westover's setting the record straight for her family and small community.
# Tara is nothing like her family.
# I thought it was amazing that Tara made it out of that family.
# Tara Westover has opened up her heart and her journals and has given us a very raw, honest, eye-opening story!In this story Tara takes us on quite a journey – starting with her childhood through her college years.
# This book has been heavily reviewed, so I will make a few observations:A difference between Tara (who eventually breaks free) and her sister-in-law (who doesn’t) is that Tara goes to great lengths to hide (to others and to herself) her shame.
# Some parts were difficult to read and others frustrating, but I always wanted to know how Tara would survive her family.
# Tara does such an amazing job of telling her story.
# I am amazed at the drive and resiliency of Tara as she pulls herself out of a horrible family situation.
#
#
# Cluster #2 sentences (density score: 0.367):
#
# Tara Westover describes her unconventional and brutal upbringing growing up in the mountains of Idaho in a Mormon family.
# Raised by Mormon survivalists in the mountains of Idaho her life was incredibly different than anything I can even imagine.
# Tara Westover was raised in a survivalist, fundamentalist Mormon family in the mountains of Idaho.
# Educated is a memoir by Tara Westover, who was raised by Mormon zealots in rural Idaho.
# Growing up in a Mormon family in Idaho, Tara and her siblings were sheltered from most modern civilization and were vilified by their father for wanting to attend school.
# Westover relates her tale of growing up in an extremely religious Mormon fundamentalist family with a domineering survivalist father in rural Idaho.
# Educated  is a memoir of Tara Westover's unusual upbringing in a fundamentalist Mormon household in rural Idaho.
# Tara grew up in the mountains of Idaho born to a Mormon survivalist family.
#
#
# Cluster #3 sentences (density score: 0.332):
#
# This was quite honestly the best memoir that I've ever read.
# It was one of the best books I've ever read.
# As I noted before, this book is very well written and is a compelling read.
# I’ll be honest some chapters were hard to read, but overall I felt like this book was so beautifully written and I am so glad, I took the time to read it !
# I had a really tough time reading this book.
# I believe this is the first memoir I’ve ever read & it captivated me deeply.
# I did enjoy the book from the beginning and I think it is well written (for a memoir), even though there are gaps in the story.
# This well written memoir is a book I would recommend for any book lover.
#
#
# Cluster #4 sentences (density score: 0.266):
#
# It is absolutely incredible she was able to get out of that situation and educate herself as much as she has.
# She goes to great lengths to try to corroborate her story and I think she does well, but I would not at all be surprised if there were members of her family and of her community that were distressed by the publication of this book.
# I identify with her being hell-bent on getting educated and knowing she had to do it herself.
# The fact that she made it out alive amazes me more than the fact that she got into college.
# Her story is hard to believe, but her skill at relating it - and her cogent self-analysis - makes this an unforgettable memoir.
# This was inculcated into her, to such a degree, that as a child and adolescent she had no idea that her life, was in fact, a living hell.
# Difficult to understand how she would keep going back to her family for acceptance and validation, even after successfully turning her life around with an education any scholar would aspire to, and after that family spread vicious lies about her.
# It was grueling to read about all that she went through as a child with her parents and her siblings.
#
#
# Cluster #5 sentences (density score: 0.251):
#
# These were abusive on their own, but an important part of the abuse Westover experienced came from her family's twisting of the truth to match her father's and brother's stories.
# Emotional and physical, Tara's story is most impressive that not only did she break out and get an education, but she escaped the abuse from her father and brother that kept all the rest of her family in check.
# The abuse in this story - the physics abuse by her brother, the gaslighting by her parents, the lack of adequate healthcare that constitutes abuse, the brainwashing about gender roles and basic history, it’s all so startling.
# In Educated, Tara shared her inspiring, often scarred -- both mentally and physically -- story of growing up in a fundamentalist home with an abusive and neglectful family.
# I’m sad that reconciling her familial love with her education had to mean distancing herself from parents who (allegedly) chose extremist beliefs—and a very troubled son—over their gifted daughter.
# Her upbringing was brutal at times and made for difficult reading - the family did not believe in using hospitals or doctors and some of the injuries depicted are truly horrific, how they managed to survive through most of them is beyond me.
# She has to cope with a mentally ill white nationalist father, a criminally abusive and possibly psychopathic brother who believes he is chosen by God, and an all too spellbound mother who seems incapable of adequately protecting her children from the dangers from within the family.
# That setup -- extremely religious parents, no medical care, no structured schooling -- combined with violent and abusive relatives, created a childhood for Tara that was so shocking I often had to pause the book and marvel that she survived.
#
#
# Cluster #6 sentences (density score: 0.14):
#
# I never knew some people intentionally choose to live that way.
# I'm sure not everyone will be as entranced in this narrative as I was.
# to think that someone had to go through something like that is so foreign to me bc i’ve never experienced that and i’m ever so grateful for it.
# There are things that are so unbelievable that I still am not sure if it was totally the truth.
# It’s a tough read and I almost had to stop a couple of times – imagine living it!
# I didn't get what many people were hoping I would from Educated.
# Hearing Tara's story makes me question if I would have had the same desire and drive to educate myself if it wasn't just something that was automatically part of my life.
# While reading this I could think of people I know who act similarly, and that alone is a hard truth.
#
#
# Model density score: 0.28738

# %%
# Get sentence clusters for bad reviews
sentences, sentence_vectors = filter_reviews(ed_file_path, 1, 2)
get_clusters(sentences, sentence_vectors, k=6, n=8)
# Out:
# Cluster #1 sentences (density score: 0.445):
#
# I really wanted to enjoy this book, I just didn't.
# I'm just not sure why I really didn't like this book that much.
# I couldn’t stop reading this book.
# I disliked this book probably more than just about any book I have ever read.
# I hate giving books up, but this book was “meh”.
# Just wasn't worth my time reading this book.
# I really should never have read this book.
# Meh, this book really didn't do alot for me.
#
#
# Cluster #2 sentences (density score: 0.314):
#
# While she certainly has crafted an interesting story of abuse and religious extremism, she never made me feel anything other than horror of the abuse in her situation and hatred of her brother and father.
# Her re-telling of countless acts of abuse by her brother and mental abuse by her parents became redundant to say the least.
# I truly think she would have stayed with the family if her parents hadn’t turned a blind eye towards her brother’s abuse.
# What I couldn’t get over was how dysfunctional and abusive her family was.
# I’m very impressed that the author escaped from her difficult childhood and her troubling /abusive family.
# The one part of her story I refuse to poke holes into is the emotional and physical abuse she sustained from her family, mainly from her father and her brother, Shawn.
# It was also hard to read about the abuse Tara and her extended family were subjected to at the hands of her older brother.
# So while Tara has some serious complaints, to me this book was really about her angst towards her father and her abusive brother.
#
#
# Cluster #3 sentences (density score: 0.307):
#
# As much as this is a memoir and clearly you cannot remember everything "correctly" in life, I really do think the author exaggerated most of the stories in the book to make her life seem more interesting!
# There's no doubt that she has an amazing life story; I just didn't enjoy reading a whole book about it that much.
# I don't know what to say about this memoir, except that it is written by such an unreliable narrator, that I find it odd it was published at all.
# I have never read a memoir where the author is so emotionally detached and uninvested in the book.
# That said, a book is more than the plot line, and I don't think I would have enjoyed the writing style of this book if the story had been any less interesting.
# ” It really is a very good story, but no way is it a “memoir.
# One reason I dislike memoirs is because the reader is left to wonder how much of the story is embellished to make it more interesting.
# I should start this by saying I'm not the biggest memoir reader- so memoirs are not typically my thing (so I'm not too surprised that this just wasn't the book for me).
#
#
# Cluster #4 sentences (density score: 0.274):
#
# I still found it very unpleasant to read.
# It reminded me that I don’t like reading memoirs, but the whole thing just bugged me.
# I dunno, it was just getting to be a bit much for me to believe.
# Oh well, at least it was a quick read.
# I didn't enjoy this at all, and I believed even less of it.
# I didn’t find it interesting at all.
# That was a bit odd to me, but the book was still enjoyable at this point.
# I just couldn’t get into this story for whatever reason.
#
#
# Cluster #5 sentences (density score: 0.266):
#
# It crossed my mind that maybe she was so sheltered / naive that she doesn't realize how fortunate she is in the higher education she received.
# I Googled her to see what she has done with her education, but so far, the only thing that came up was this book.
# I find myself wondering if after she finished all her schooling wasn’t sure what to do with herself and was so fixated on her family that she decided to “write what she knew”.
# I thought it was going to be a book about how she grew and became a better person through her opportunity receive an education.
# She has gained an education, but never seems to learn how to really LIVE.
# I'm not sure how she handled school with all of the crap that her family put on her, let alone obtaining a PhD.
# I am impressed she was able to get as much education as she has.
# She repeats over and over that she never had an education before she left home, but I don't think she gives her mother enough credit for teaching her the skills she needed to teach herself.
#
#
# Cluster #6 sentences (density score: 0.134):
#
# It seems that she believes she is an exception in this world but I am sure she is not the first nor the only person coming from poor and violent backgrounds to get degrees from top schools.
# Ok lots and lots of rural families “home school” and unfortunately do not immunize their children.
# I think being a part of a religious fundamental family would be tough and things would feel exaggerated and when you see a world and life so different from your own.
# I think it’s great that she made a life for herself while not being formally educated as a child and living in such a dysfunctional family.
# I kept thinking it must be called Uneducated as it dealt with the author’s horrendous upbringing in a dysfunctional family, yet she seems to have learned nothing by the end of the book.
# The facts don’t add up I guess I thought The book would give an understanding about growing up Mormon, on the contrary seems to be about growing up with mental illness- in most of the family.
# it kind of looks like there was a lottery and you either came out on the genius side or the mentally ill side), or they received more education in their home life then they lead us to believe.
# I know this book "wasn't about Mormonism" but it certainly leads credence to the cries of poor homeschooling families out there, as well as the backwater medicine practices, and, yes, Mormonism.
#
#
# Model density score: 0.29023

# %% [markdown]
# Here again filtering seems to produce better and more easily interpretable results.
#
# Let's look at one last book, Ted Chiang's *Exhalation*, also scraped from GoodReads.

# %%
ex_file_path = 'data/41160292_exhalation_stories.csv'

sentences, sentence_vectors = load_sentences(ex_file_path)
# Out:
# This dataset consists of 7059 sentences from 937 reviews

# %%
# Get sentence clusters
get_clusters(sentences, sentence_vectors, k=8, n=8)
# Out:
# Cluster #1 sentences (density score: 0.557):
#
# "Anxiety is the dizziness of freedom" is the last story, and probably the most imaginative.
# I also really enjoyed "Anxiety Is the Dizziness of Freedom".
# 'Anxiety is the Dizziness of Freedom' was definitely my favourite.
# Anxiety is the Dizziness of Freedom - This one is a pure masterpiece, also a candidate for my favorite story.
# “Anxiety Is the Dizziness of Freedom” is another favorite.
# "Anxiety is the Dizziness of Freedom" has a great title and a satisfying ending.
# :)Anxiety Is the Dizziness of Freedom - Another novella, and fascinating as hell.
# "Anxiety is the Dizziness of Freedom" is probably the second greatest in the book.
#
#
# Cluster #2 sentences (density score: 0.505):
#
# 'The Merchant and the Alchemist's Gate' is a delightfully engaging time-travel tale.
# I loved the first story, “The Merchant and the Alchemist's Gate”.
# The first story, "The Merchant and the Alchemist's Gate," was really good.
# Merchant and the Alchemist's Gate was my favorite story.
# The first story, "The Merchant and the Alchemist's Gate," really drew me in.
# The first story ("The Merchant and the Alchemist's Gate") is terrific; a must-read.
# The first two stories (The Merchant and the Alchemist’s Gate & Exhalation) are very good.
# That said, I loved the first story, The Merchant and the Alchemist's Gate.
#
#
# Cluster #3 sentences (density score: 0.43):
#
# Ted Chiang is maybe the best living writer of the science-fiction short story.
# Ted Chiang is crazy good!Exhalation is a collection of short stories written by Ted Chiang over the years.
# I love whenever a new Ted Chiang short story comes out.
# I cannot say if Ted Chiang is as insightful and creative as his short stories lead me to believe.
# I believe Ted Chiang is likely the best writer I've ever had the privilege of reading.
# Ted Chiang is my favorite short story writer and having a new collection of his to read is awesome!
# Ted Chiang is king of the short story.
# Ted Chiang is quite possibly our greatest living short story writer.
#
#
# Cluster #4 sentences (density score: 0.415):
#
# I don’t read much science fiction or short stories, but really enjoyed this!
# This book made me realize that, even though I am a sci-fi fan, I don't usually read contemporary sci-fi, but I tend to go for the classics, like Asimov or Sturgeon.
# Science fiction is not normally my thing to read, although I enjoy a good sci-fi movie now and then.
# I typically don't read sci-fi and I've never been much of a short story enthusiast.
# This is a challenging book of short stories that I suppose some might call “science fiction” but in some cases are more “human fiction”.
# I would highly recommend it - it feels like it certainly transcends its science fiction label (not that science fiction is a bad thing, but this has nothing of the negatives often associated with hard sci-fi, even though it is definitely science fiction).
# Overall though, this is a great little set of philosophical sci fi stories that I'm glad I read.
# I usually like sci fi and futuristic novels and short stories, but this collection left me cold.
#
#
# Cluster #5 sentences (density score: 0.399):
#
# I enjoyed this book but, as with most collections of short stories, I felt like some of the stories really missed the mark.
# Well written short story collection, but sadly I didn't connect with a high percentage of the stories collected.
# I often have a hard time reading short story collections start to finish - but I really loved the variety in the stories.
# I mean, sure, like every other short story collection, there are stories that didn't work for me.
# I'll be honest, I enjoyed Chiang's original book of short stories (Story of Your Life and Others) a lot more than this collection.
# A few of the stories were drawn out for the story they told, but overall an enjoyable read.
# I enjoyed this book, but some of the stories more than others.
# I really liked some of the shorter stories in this collection.
#
#
# Cluster #6 sentences (density score: 0.307):
#
# The stories in Exhalation: Stories attempt to plumb similarly deep and interesting themes, but for this reader at least, none of the characters feel particularly real as characters.
# This was my first foray into his work and while the stories sit upon some really mind-opening (in one case, literally) ideas, I was not really pulled in by much of the prose or directions of the narratives.
# The ideas and themes Exhalation explores are wondrous, but I felt a few too many times that the stories placed plot over character, which didn’t lessen my enjoyment, but they didn’t quiet resonate as strongly.
# Much like with his previous collection, I found the story notes and Chiang’s thoughts on technology and it’s impact on humanity far more interesting than the stories themselves.
# As imaginative as ever, Chiang’s ideas are truly grand and original, but this batch of tales felt less like short stories than dry allegories to push his questions forward.
# He has a definite style that is apparent in all the stories -- in terms of character development and backstory telling -- that is too time consuming and detailed for my short story tastes.
# The story within a story within a story format was very intriguing, and while I was confused slightly sometimes, the stories were like parables with interesting lessons and I enjoyed them a lot.
# With short stories, I always feel frustrated, I want more) but you have to admit that the stories are really interesting and explore very interesting ideas.
#
#
# Cluster #7 sentences (density score: 0.208):
#
# I didn't find myself enjoying the read much though.
# I liked this book, at least I wanted to, but every time I opened this it felt like a chore.
# I don't really know what else to say about this one other than I loved it!
# I enjoyed this one even more than Chiang’s first collection, having trouble putting it down.
# I didn't like it that much but still had interest to see the end.
# I enjoyed the book, but not as much as the blurbs led me to expect.
# I didn't enjoy this collection as much as the last one.
# I'm not sure which one I liked the most, I almost need to reread them all.
#
#
# Cluster #8 sentences (density score: 0.189):
#
# A new invention is created that demonstrates the humans have no free will and then explores how this affects humanity.
# There are forays into interspecies communication ("The Great Silence," my favorite), artificial intelligence, strange methods of child-rearing, communication with parallel universes, "Young Earth" theory, alternative biochemistry, free will, memory, and the emotional and moral implications of time-traveling along one's own timeline.
# What is different here is that Ted’s stories that are of the now, though the concepts are pretty timeless – the questioning nature of Humanity, the need of humans for company and contact in an increasingly complex technological world, the unintended consequences of technology on a unsuspecting world.
# What if we were all robots exploring how our minds work but realising that our time on earth is finite?
# The third story is a short thought experiment on the effects of humanity finding out free will is an illusion, and somehow I didn’t respond to it as much as the other stories.
# I found these to be rather peculiar, futuristics stories about time travel, free will and how the choices we make can completely alter our lives, for instance.
# Rating: ⭐️⭐️⭐️⭐️ What’s Expected Of Us This was a fascinating tale about what would happen if humans realize there is no such thing as free will and everything is predetermined, and what kind of consequences can occur due to this shattering of the illusion.
# Computer programs that provide "a prism" to create an alter self and compare that para-self's life to your own, theories about the creation of the universe, and AI robots who get trained/educateed to become like humans in every way eventually, etc.
#
#
# Model density score: 0.37618

# %%
# Get sentence clusters for good reviews
sentences, sentence_vectors = filter_reviews(ex_file_path, 4, 5)
get_clusters(sentences, sentence_vectors, k=6, n=8)
# Out:
# Cluster #1 sentences (density score: 0.563):
#
# "Anxiety is the dizziness of freedom" is the last story, and probably the most imaginative.
# 'Anxiety is the Dizziness of Freedom' was definitely my favourite.
# “Anxiety Is the Dizziness of Freedom” is another favorite.
# "Anxiety is the Dizziness of Freedom" has a great title and a satisfying ending.
# :)Anxiety Is the Dizziness of Freedom - Another novella, and fascinating as hell.
# Anxiety is the Dizziness of Freedom - This one is a pure masterpiece, also a candidate for my favorite story.
# "Anxiety is the Dizziness of Freedom" is probably the second greatest in the book.
# Anxiety Is the Dizziness of Freedom ( Well thought out)
#
#
# Cluster #2 sentences (density score: 0.438):
#
# Ted Chiang is maybe the best living writer of the science-fiction short story.
# I love whenever a new Ted Chiang short story comes out.
# Ted Chiang is my favorite short story writer and having a new collection of his to read is awesome!
# I cannot say if Ted Chiang is as insightful and creative as his short stories lead me to believe.
# Ted Chiang is king of the short story.
# I believe Ted Chiang is likely the best writer I've ever had the privilege of reading.
# Ted Chiang is quite possibly our greatest living short story writer.
# Ted Chiang has done it again with an amazing collection of stories.
#
#
# Cluster #3 sentences (density score: 0.36):
#
# I enjoyed this book but, as with most collections of short stories, I felt like some of the stories really missed the mark.
# I often have a hard time reading short story collections start to finish - but I really loved the variety in the stories.
# I also appreciate "story notes", as these often lead me to read whatever inspired that particular short story.
# A few of the stories were drawn out for the story they told, but overall an enjoyable read.
# I mean, sure, like every other short story collection, there are stories that didn't work for me.
# This was an amazing book (much like his last), and some of my favorite short stories I've ever read.
# This was a very solid collection and I liked pretty much all the stories in it.
# I didn't absolutely love all the stories in this collection, but the ones I did made reading the book worth it.
#
#
# Cluster #4 sentences (density score: 0.339):
#
# Much like in his first collection of short stories, Stories of Your Life and Others, Chiang utilizes sci-fi elements to explore heavy philosophical issues, making his writing as thought-provoking as it is entertaining.
# A fascinating collection of very different “sci-fi” type stories that really get you thinking.
# The title story is one of the most interesting science fiction stories I've read in a really long time
# Like the sci-fi masters of the Old, Chiang is still keen on the science part of the genre and stories combined in Exhalation are great examples of science fiction as an “idea literature”.
# I don’t read much science fiction or short stories, but really enjoyed this!
# "The Merchant and the Alchemist's Gate": This is the first story of the collection and also the one that felt the least "sci-fi" to me and had a much stronger fantasy fairy tale/child story sort of vibe.
# This is a challenging book of short stories that I suppose some might call “science fiction” but in some cases are more “human fiction”.
# Intelligent science fiction stories with good plots and interesting thought experiments.
#
#
# Cluster #5 sentences (density score: 0.229):
#
# What is different here is that Ted’s stories that are of the now, though the concepts are pretty timeless – the questioning nature of Humanity, the need of humans for company and contact in an increasingly complex technological world, the unintended consequences of technology on a unsuspecting world.
# A new invention is created that demonstrates the humans have no free will and then explores how this affects humanity.
# For such a short story it deals with impressively big questions, a story of self-discovery by a robot determined to discover how he works and who reveals to himself concepts on the nature of the universe and what is it that makes us human.
# "What's expected of us" is the first of the stories that deal with free will, and goes directly into the heart of it, with a first person narrative of one's reaction when confronted with immutable proof that it doesn't exist!
# The third story is a short thought experiment on the effects of humanity finding out free will is an illusion, and somehow I didn’t respond to it as much as the other stories.
# Most of the stories seem like meditations on Free Will, a concept that has a publishing history of its own, so much so that it seems futile to even argue about it.
# It turns out that the disabling thought is one that we’ve all encountered: the idea that free will doesn’t existThe ending to this story is worded with brilliant and incisive commentary on human condition, tying the plot together.
# There are forays into interspecies communication ("The Great Silence," my favorite), artificial intelligence, strange methods of child-rearing, communication with parallel universes, "Young Earth" theory, alternative biochemistry, free will, memory, and the emotional and moral implications of time-traveling along one's own timeline.
#
#
# Cluster #6 sentences (density score: 0.141):
#
# Even the few stories I wasn't as engaged in still made me feel like my mind was being slightly blown.
# I also thought the ending was a bit too neat.
# I don't really know what else to say about this one other than I loved it!
# It was an interesting one but too long in my opinion.
# I'm not convinced it would play out this way but it's certainly and interesting way to look at it.
# I consider it one of the best stories I've ever read.
# This was my least favorite, but still, interesting concept.
# I didn't like it that much but still had interest to see the end.
#
#
# Model density score: 0.34489

# %%
# Get sentence clusters for bad reviews
sentences, sentence_vectors = filter_reviews(ex_file_path, 1, 2)
get_clusters(sentences, sentence_vectors, k=6, n=8)
# Out:
# Cluster #1 sentences (density score: 0.46):
#
# I liked the first short story the most (“The Merchant and the Alchemist's Gate”) and the never ending story on digients (“The Lifecycle of Software Objects”) the least.
# I loved the first story, “The Merchant and the Alchemist's Gate”.
# That said, I loved the first story, The Merchant and the Alchemist's Gate.
# The first story, "The Merchant and the Alchemist's Gate," was really good.
# I liked the first story very much “The merchant and alchemist gate”.
# The first story, "The Merchant and the Alchemist's Gate," really drew me in.
# My favorite story was the Merchant and the Alchemists Gate and least favorite was the Lifecycle of Software Objects.
# The only story to grab my attention was "The Merchant and The Alchemist Gate. "
#
#
# Cluster #2 sentences (density score: 0.446):
#
# I love science fiction so it was not a genre issue.
# The thing that made this book so boring is that the stories were not very sci-fi but more philosophical.
# Some of the stories were interesting, but it’s mostly exploring sci-fi ideas and not much (or weak) plot.
# Full disclosure: I am not a sci-fi fan per se but I have enjoyed science fiction that makes me question my existence and the human condition.
# I usually like sci fi and futuristic novels and short stories, but this collection left me cold.
# Stories were just too weird for me, a combination of science fiction, philosophy, and physics.
# Didn't realize it was going to be sci-fi.
# I was looking forward to imaginative, thought-provoking scifi, something along the lines of Black Mirror.
#
#
# Cluster #3 sentences (density score: 0.446):
#
# I really enjoyed some of the stories, though.
# A couple of the stories were very good, but most just didn't interest me that much.
# I liked only about half the stories.
# This short story collection had more underwhelming stories than standout ones.
# The first 2 stories were just OK.  And then came the "Digian" story.
# I enjoyed the first two stories.
# I guess that maybe I was expecting short stories more than novellas.
# I really liked some of the shorter stories in this collection.
#
#
# Cluster #4 sentences (density score: 0.376):
#
# I just couldn't get into this book.
# This book just wasn’t for me
# I got this book for my birthday, and even though I didn't like the first book, decided to read this one anyway.
# I thought, "This book is going to be great. "
# Again, overall I didn't like this book, but it's not the books fault.
# I liked this book, at least I wanted to, but every time I opened this it felt like a chore.
# As a fan of Chiang's previous collection of stories, I was disappointed with this book.
# The author has won so many awards, so take this review as one by a reader who just wants to say this book clearly was not for me.
#
#
# Cluster #5 sentences (density score: 0.32):
#
# Conceptually most of these stories are great, but Chiang has failed to fully flesh them out with appealing or empathetic characters, and as a result they read more like thought experiments than real stories, delivered with clunky prose and wooden dialogue.
# Chiang is clearly full of ideas and concepts, many of which are interesting, but the man is just not a good writer.
# This was my first foray into his work and while the stories sit upon some really mind-opening (in one case, literally) ideas, I was not really pulled in by much of the prose or directions of the narratives.
# Chiang is a very subdued author so the ideas without compelling characters or plots only took me so far.
# The stories and the prose are more just vessels for Chiang’s ideas than actual stories themselves.
# The author seems much more interested in expanding on a concept than telling a story, and sometimes his fixations are on ideas that I personally find dry and perhaps unworthy of this much attention (the title story, "Exhalation", for example).
# The stories lack the masterful insight and imagination that those of his first book had.
# The stories are good as ideas but the author does not develop them in a way for the reader to care.
#
#
# Cluster #6 sentences (density score: 0.205):
#
# A couple of the stories were very good, but most just didn't interest me that much.
# some interesting ideas but characters seemed very flat and uninteresting.
# Overall boring, and I couldn't wait for it to be over.
# Some of them were too long, some a little boring.
# There were a few interesting conceptual ideas, and that's all I got out of it.
# Some really cool concepts, but the execution wasn't to my taste.
# I found myself bored for the majority of it, setting it aside for weeks at a time before I forced myself back because "maybe the next one is better".
# Maybe this one will be better in later stories but I don't feel like finding out.
#
#
# Model density score: 0.3755

# %% [markdown]
# In this case, the full set of reviews seems to produce more helpful results than the filtered sets of reviews. This just goes to show that there is no hard and fast rule about which settings will produce the most meaningful results: the appropriate setting will depend on the book, its reviews, and the needs of the user.
#
# In conclusion, we have shown in this notebook that our model still performs well on relatively small datasets, of even only 100 reviews. This means that we shouldn't feel constrained in the size of datasets we can work with. We have also shown that, while filtering reviews by their rating produces better results in some cases, it produces worse results in others. Because of this, review filtering should be left as an parameter than can be set by the user.
